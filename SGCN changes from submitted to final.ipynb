# %% [markdown]
# # Show changes made to the SGCN data from submitted to final

# %% [markdown]
# In the production of the integrated species lists from State Wildlife Action Plans in 2005 and submitted Species of Greatest Conservation Need in 2015, the USGS goes through some data harmonization steps to integrate a complete list, find alignment with taxonomic authorities, and produce a synthesized national list. In this process, the original submitted species names are "cleaned" to make them into searchable strings, corrected for misspellings, and eventually aligned with a taxonomic authority to integrate the information into a national list.
#
# This notebook presents a different way of looking at the changed/corrected names than what is presented in the current SWAP app. It is entirely driven by a simple query of the data to look for cases where the original submitted name does not match the final accepted name. We will need to modify the application to work against this query and include the following documentation.
#
# The table shows all of the cases where the original submitted species name (Submitted column) was altered in some way to produce the final state/national list of accepted names (Accepted column).
#
# * A value in the "Cleaned" column indicates that some alteration was made to the submitted name in order to make it feasible to run a taxonomic authority search.
# * A value in the "Corrected" column indicates that a basic correction was made in spelling (often Latin spelling corrections) in order to make the taxonomic authority search more direct.
# * The "TaxonomicID Discovered" column shows the identifier discovered based on the cleaned or corrected name in the relevant taxonomic authority (ITIS or WoRMS).
# * The "TaxonomicID Accepted" column shows the identifier that was used to produce the accepted name for the species.
# * A difference between the Discovered and Accepted taxonomic IDs indicates a case where the taxonomic authority pointed to a current or corrected taxonomic record for the species.

# %%
import requests

gc2BaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb"

# %%
#Class to render tables
class ListTable(list):
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %% [markdown]
# This query grabs all of the cases where the final accepted name did not match the original submitted name and shows the relevant properties to understand what was changed. The query can be modified to include a "where state=???" to show on each state page.

# %%
sqlGetChangedNames = "\
    SELECT sgcnyear,scientificname_accepted,scientificname_cleaned,scientificname_submitted,\
    scientificname_corrected,taxonomicauthorityid_discovered,taxonomicauthorityid_accepted \
    FROM sgcn \
    WHERE scientificname_submitted <> scientificname_accepted \
    AND scientificname_accepted <> '' \
    ORDER BY sgcnyear,scientificname_accepted"
queryURL = gc2BaseURL+"?q="+sqlGetChangedNames
changedNames = requests.get(queryURL).json()

print ('Number of original names submitted that did not align with final taxonomic authority names: '+str(len(changedNames['features'])))

table = ListTable()
table.append(['Year', 'Submitted', 'Cleaned', 'Corrected', 'Accepted', 'TaxonomicID Discovered', 'TaxonomicID Accepted'])
for feature in changedNames['features']:
    table.append([\
        feature['properties']['sgcnyear'], \
        feature['properties']['scientificname_submitted'], \
        feature['properties']['scientificname_cleaned'], \
        feature['properties']['scientificname_corrected'], \
        feature['properties']['scientificname_accepted'], \
        feature['properties']['taxonomicauthorityid_discovered'], \
        feature['properties']['taxonomicauthorityid_accepted'] \
        ])
table
# Out:
# Number of original names submitted that did not align with final taxonomic authority names: 4654
# [['Year',
#   'Submitted',
#   'Cleaned',
#   'Corrected',
#   'Accepted',
#   'TaxonomicID Discovered',
#   'TaxonomicID Accepted'],
#  [2005,
#   'Abacion tessalatum',
#   'Abacion tessalatum',
#   'Abacion tesselatum',
#   'Abacion tesselatum',
#   'http://services.itis.gov/?q=tsn:570281',
#   'http://services.itis.gov/?q=tsn:570281'],
#  [2005,
#   'Abagrotis barnesi',
#   'Abagrotis barnesi',
#   '',
#   'Abagrotis orbis',
#   'http://services.itis.gov/?q=tsn:940756',
#   'http://services.itis.gov/?q=tsn:771360'],
#  [2005,
#   'Acalypta lillianus',
#   'Acalypta lillianus',
#   'Acalypta lillianis',
#   'Acalypta lillianis',
#   'http://services.itis.gov/?q=tsn:104186',
#   'http://services.itis.gov/?q=tsn:104186'],
#  [2005,
#   'Acantharcus pomotis',
#   'Acantharcus pomotis',
#   'Acantharchus pomotis',
#   'Acantharchus pomotis',
#   'http://services.itis.gov/?q=tsn:168095',
#   'http://services.itis.gov/?q=tsn:168095'],
#  [2005,
#   'Carduelis hornemanni',
#   'Carduelis hornemanni',
#   '',
#   'Acanthis hornemanni',
#   'http://services.itis.gov/?q=tsn:179231',
#   'http://services.itis.gov/?q=tsn:179238'],
#  [2005,
#   'Acanthocyclops Columbiensis',
#   'Acanthocyclops Columbiensis',
#   '',
#   'Acanthocyclops columbiensis',
#   'http://services.itis.gov/?q=tsn:667129',
#   'http://services.itis.gov/?q=tsn:667129'],
#  [2005,
#   'Accipiter Cooperii',
#   'Accipiter Cooperii',
#   '',
#   'Accipiter cooperii',
#   'http://services.itis.gov/?q=tsn:175309',
#   'http://services.itis.gov/?q=tsn:175309'],
#  [2005,
#   'Accipiter gentilus',
#   'Accipiter gentilus',
#   'Accipiter gentilis',
#   'Accipiter gentilis',
#   'http://services.itis.gov/?q=tsn:175300',
#   'http://services.itis.gov/?q=tsn:175300'],
#  [2005,
#   'Accipiter gentilus atricapillus',
#   'Accipiter gentilus atricapillus',
#   'Accipiter gentilis atricapillus',
#   'Accipiter gentilis atricapillus',
#   'http://services.itis.gov/?q=tsn:175301',
#   'http://services.itis.gov/?q=tsn:175301'],
#  [2005,
#   'Accipiter gentilus laingi',
#   'Accipiter gentilus laingi',
#   'Accipiter gentilis laingi',
#   'Accipiter gentilis laingi',
#   'http://services.itis.gov/?q=tsn:175302',
#   'http://services.itis.gov/?q=tsn:175302'],
#  [2005,
#   'Achatinella spp.',
#   'Achatinella',
#   '',
#   'Achatinella',
#   'http://services.itis.gov/?q=tsn:198380',
#   'http://services.itis.gov/?q=tsn:198380'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhynchus',
#   'Acipenser oxyrhynchus',
#   '',
#   'Acipenser oxyrinchus',
#   'http://services.itis.gov/?q=tsn:573257',
#   'http://services.itis.gov/?q=tsn:553269'],
#  [2005,
#   'Acipenser oxyrhinchus desotoi',
#   'Acipenser oxyrhinchus desotoi',
#   'Acipenser oxyrhynchus desotoi',
#   'Acipenser oxyrinchus desotoi',
#   'http://services.itis.gov/?q=tsn:201894',
#   'http://services.itis.gov/?q=tsn:624005'],
#  [2005,
#   'Lotus helleri',
#   'Lotus helleri',
#   '',
#   'Acmispon americanus var. helleri',
#   'http://services.itis.gov/?q=tsn:516132',
#   'http://services.itis.gov/?q=tsn:820994'],
#  [2005,
#   'Acris crepitans blanchardi',
#   'Acris crepitans blanchardi',
#   '',
#   'Acris blanchardi',
#   'http://services.itis.gov/?q=tsn:173522',
#   'http://services.itis.gov/?q=tsn:774220'],
#  [2005,
#   'Acris crepitans blanchardi',
#   'Acris crepitans blanchardi',
#   '',
#   'Acris blanchardi',
#   'http://services.itis.gov/?q=tsn:173522',
#   'http://services.itis.gov/?q=tsn:774220'],
#  [2005,
#   'Acris crepitans blanchardi',
#   'Acris crepitans blanchardi',
#   '',
#   'Acris blanchardi',
#   'http://services.itis.gov/?q=tsn:173522',
#   'http://services.itis.gov/?q=tsn:774220'],
#  [2005,
#   'Acris crepitans crepitans',
#   'Acris crepitans crepitans',
#   '',
#   'Acris crepitans',
#   'http://services.itis.gov/?q=tsn:173521',
#   'http://services.itis.gov/?q=tsn:173520'],
#  [2005,
#   'Acrocephalus luscinia',
#   'Acrocephalus luscinia',
#   '',
#   'Acrocephalus luscinius',
#   'http://services.itis.gov/?q=tsn:178669',
#   'http://services.itis.gov/?q=tsn:916778'],
#  [2005,
#   'Emys (=Clemmys) marmorata pallida',
#   'Emys marmorata pallida',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:668677',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Clemmys marmorata',
#   'Clemmys marmorata',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:173774',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Emys (=Clemmys) marmorata',
#   'Emys marmorata',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:208592',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Emys (=Clemmys) marmorata marmorata',
#   'Emys marmorata marmorata',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:668676',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Emys marmorata marmorata',
#   'Emys marmorata marmorata',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:668676',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Actinemys (Clemmys) marmorata',
#   'Actinemys marmorata',
#   '',
#   'Actinemys marmorata',
#   'http://services.itis.gov/?q=tsn:668668',
#   'http://services.itis.gov/?q=tsn:668668'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Actitis macularia',
#   'Actitis macularia',
#   '',
#   'Actitis macularius',
#   'http://services.itis.gov/?q=tsn:176612',
#   'http://services.itis.gov/?q=tsn:726049'],
#  [2005,
#   'Adetus sp. EGR 1',
#   'Adetus',
#   '',
#   'Adetus',
#   'http://services.itis.gov/?q=tsn:701755',
#   'http://services.itis.gov/?q=tsn:701755'],
#  [2005,
#   'Aerodramus vanikorensis bartschi',
#   'Aerodramus vanikorensis bartschi',
#   '',
#   'Aerodramus bartschi',
#   'http://services.itis.gov/?q=tsn:202275',
#   'http://services.itis.gov/?q=tsn:554964'],
#  [2005,
#   'Aerodramus vanikorensis bartschi',
#   'Aerodramus vanikorensis bartschi',
#   '',
#   'Aerodramus bartschi',
#   'http://services.itis.gov/?q=tsn:202275',
#   'http://services.itis.gov/?q=tsn:554964'],
#  [2005,
#   'Agallissus lepturoides (Chevrolat)',
#   'Agallissus lepturoides',
#   '',
#   'Agallissus lepturoides',
#   'http://services.itis.gov/?q=tsn:702422',
#   'http://services.itis.gov/?q=tsn:702422'],
#  [2005,
#   '?Agastoschizomus n.sp.',
#   'Agastoschizomus',
#   '',
#   'Agastoschizomus',
#   'http://services.itis.gov/?q=tsn:690796',
#   'http://services.itis.gov/?q=tsn:690796'],
#  [2005,
#   'Agkistrodon contortix',
#   'Agkistrodon contortix',
#   'Agkistrodon contortrix',
#   'Agkistrodon contortrix',
#   'http://services.itis.gov/?q=tsn:174296',
#   'http://services.itis.gov/?q=tsn:174296'],
#  [2005,
#   'Agkistsrodon contortrix',
#   'Agkistsrodon contortrix',
#   'Agkistrodon contortrix',
#   'Agkistrodon contortrix',
#   'http://services.itis.gov/?q=tsn:174296',
#   'http://services.itis.gov/?q=tsn:174296'],
#  [2005,
#   'Agkistrodon c. mokasen',
#   'Agkistrodon contortrix mokasen',
#   '',
#   'Agkistrodon contortrix mokasen',
#   'http://services.itis.gov/?q=tsn:174297',
#   'http://services.itis.gov/?q=tsn:174297'],
#  [2005,
#   'Agra oblongopunctata oblongopunctata (Chevrola',
#   'Agra oblongopunctata oblongopunctata',
#   '',
#   'Agra oblongopunctata oblongopunctata',
#   'http://services.itis.gov/?q=tsn:933283',
#   'http://services.itis.gov/?q=tsn:933283'],
#  [2005,
#   'Agrilus dollii (Schaeffer)',
#   'Agrilus dollii',
#   'Agrilus dolli',
#   'Agrilus dolli',
#   'http://services.itis.gov/?q=tsn:809425',
#   'http://services.itis.gov/?q=tsn:809425'],
#  [2005,
#   'Agrilus subtropicus (Schaeffer)',
#   'Agrilus subtropicus',
#   '',
#   'Agrilus subtropicus',
#   'http://services.itis.gov/?q=tsn:809529',
#   'http://services.itis.gov/?q=tsn:809529'],
#  [2005,
#   'Agrostis exarata var. minor',
#   'Agrostis exarata var. minor',
#   '',
#   'Agrostis exarata',
#   'http://services.itis.gov/?q=tsn:526864',
#   'http://services.itis.gov/?q=tsn:40412'],
#  [2005,
#   'Agrostis borealis',
#   'Agrostis borealis',
#   '',
#   'Agrostis mertensii',
#   'http://services.itis.gov/?q=tsn:40407',
#   'http://services.itis.gov/?q=tsn:182507'],
#  [2005,
#   'Hemignathus procerus',
#   'Hemignathus procerus',
#   '',
#   'Akialoa stejnegeri',
#   'http://services.itis.gov/?q=tsn:179572',
#   'http://services.itis.gov/?q=tsn:997881'],
#  [2005,
#   'Alasmidonta undulate',
#   'Alasmidonta undulate',
#   'Alasmidonta undulata',
#   'Alasmidonta undulata',
#   'http://services.itis.gov/?q=tsn:79919',
#   'http://services.itis.gov/?q=tsn:79919'],
#  [2005,
#   'Allium schoenoprasum var. sibiricum',
#   'Allium schoenoprasum var. sibiricum',
#   '',
#   'Allium schoenoprasum',
#   'http://services.itis.gov/?q=tsn:526875',
#   'http://services.itis.gov/?q=tsn:42636'],
#  [2005,
#   'Allium burdickii',
#   'Allium burdickii',
#   '',
#   'Allium tricoccum var. burdickii',
#   'http://services.itis.gov/?q=tsn:185461',
#   'http://services.itis.gov/?q=tsn:185462'],
#  [2005,
#   'Aphodius troglodytes',
#   'Aphodius troglodytes',
#   '',
#   'Alloblackburneus troglodytes',
#   'http://services.itis.gov/?q=tsn:929519',
#   'http://services.itis.gov/?q=tsn:929496'],
#  [2005,
#   'Allocragonyx pellucidus',
#   'Allocragonyx pellucidus',
#   'Allocrangonyx pellucidus',
#   'Allocrangonyx pellucidus',
#   'http://services.itis.gov/?q=tsn:95101',
#   'http://services.itis.gov/?q=tsn:95101'],
#  [2005,
#   'Alloperla vostocki',
#   'Alloperla vostocki',
#   'Alloperla vostoki',
#   'Alloperla vostoki',
#   'http://services.itis.gov/?q=tsn:103210',
#   'http://services.itis.gov/?q=tsn:103210'],
#  [2005,
#   'Alloweckellia gurnee',
#   'Alloweckellia gurnee',
#   'Alloweckelia gurneei',
#   'Alloweckelia gurneei',
#   'http://services.itis.gov/?q=tsn:900035',
#   'http://services.itis.gov/?q=tsn:900035'],
#  [2005,
#   'Alnus maritime',
#   'Alnus maritime',
#   '',
#   'Alnus maritima',
#   'http://services.itis.gov/?q=tsn:845187',
#   'http://services.itis.gov/?q=tsn:19467'],
#  [2005,
#   'Pomolobus aestivalis',
#   'Pomolobus aestivalis',
#   '',
#   'Alosa aestivalis',
#   'http://services.itis.gov/?q=tsn:161781',
#   'http://services.itis.gov/?q=tsn:161703'],
#  [2005,
#   'Alyxia oliviformis',
#   'Alyxia oliviformis',
#   '',
#   'Alyxia stellata',
#   'http://services.itis.gov/?q=tsn:30129',
#   'http://services.itis.gov/?q=tsn:893855'],
#  [2005,
#   'Amblychila picolomini',
#   'Amblychila picolomini',
#   'Amblycheila picolominii',
#   'Amblycheila picolominii',
#   'http://services.itis.gov/?q=tsn:697665',
#   'http://services.itis.gov/?q=tsn:697665'],
#  [2005,
#   'Ambystoma platineum',
#   'Ambystoma platineum',
#   '',
#   'Ambystoma laterale',
#   'http://services.itis.gov/?q=tsn:173603',
#   'http://services.itis.gov/?q=tsn:173599'],
#  [2005,
#   'Ambystoma tigrinum nebulosum',
#   'Ambystoma tigrinum nebulosum',
#   '',
#   'Ambystoma mavortium nebulosum',
#   'http://services.itis.gov/?q=tsn:208187',
#   'http://services.itis.gov/?q=tsn:668589'],
#  [2005,
#   'Ambystoma tigrinum stebbinsi',
#   'Ambystoma tigrinum stebbinsi',
#   '',
#   'Ambystoma mavortium stebbinsi',
#   'http://services.itis.gov/?q=tsn:208189',
#   'http://services.itis.gov/?q=tsn:668592'],
#  [2005,
#   'Ambytoma texanum',
#   'Ambytoma texanum',
#   'Ambystoma texanum',
#   'Ambystoma texanum',
#   'http://services.itis.gov/?q=tsn:173605',
#   'http://services.itis.gov/?q=tsn:173605'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ambystoma tigrinum tigrinum',
#   'Ambystoma tigrinum tigrinum',
#   '',
#   'Ambystoma tigrinum',
#   'http://services.itis.gov/?q=tsn:173593',
#   'http://services.itis.gov/?q=tsn:173592'],
#  [2005,
#   'Ictalurus natalis',
#   'Ictalurus natalis',
#   '',
#   'Ameiurus natalis',
#   'http://services.itis.gov/?q=tsn:164042',
#   'http://services.itis.gov/?q=tsn:164041'],
#  [2005,
#   'Ameiurus nebulosis',
#   'Ameiurus nebulosis',
#   'Ameiurus nebulosus',
#   'Ameiurus nebulosus',
#   'http://services.itis.gov/?q=tsn:164043',
#   'http://services.itis.gov/?q=tsn:164043'],
#  [2005,
#   'Amergoniscus paynei',
#   'Amergoniscus paynei',
#   'Amerigoniscus paynei',
#   'Amerigoniscus nicholasi',
#   'http://services.itis.gov/?q=tsn:900042',
#   'http://services.itis.gov/?q=tsn:594159'],
#  [2005,
#   'Amergoniscus nicholasi',
#   'Amergoniscus nicholasi',
#   'Amerigoniscus nicholasi',
#   'Amerigoniscus nicholasi',
#   'http://services.itis.gov/?q=tsn:594159',
#   'http://services.itis.gov/?q=tsn:594159'],
#  [2005,
#   'Ametropus albrighti',
#   'Ametropus albrighti',
#   '',
#   'Ametropus neavei',
#   'http://services.itis.gov/?q=tsn:101075',
#   'http://services.itis.gov/?q=tsn:101076'],
#  [2005,
#   'Ammocrypta beani',
#   'Ammocrypta beani',
#   '',
#   'Ammocrypta beanii',
#   'http://services.itis.gov/?q=tsn:168513',
#   'http://services.itis.gov/?q=tsn:553376'],
#  [2005,
#   'Etheostoma pellucidum',
#   'Etheostoma pellucidum',
#   '',
#   'Ammocrypta pellucida',
#   'http://services.itis.gov/?q=tsn:650164',
#   'http://services.itis.gov/?q=tsn:168517'],
#  [2005,
#   'Ammocrypta pellucidum',
#   'Ammocrypta pellucidum',
#   'Ammocrypta pellucida',
#   'Ammocrypta pellucida',
#   'http://services.itis.gov/?q=tsn:168517',
#   'http://services.itis.gov/?q=tsn:168517'],
#  [2005,
#   'Ammospiza maritime',
#   'Ammospiza maritime',
#   'Ammospiza maritima',
#   'Ammodramus maritimus',
#   'http://services.itis.gov/?q=tsn:179355',
#   'http://services.itis.gov/?q=tsn:179346'],
#  [2005,
#   'Ammodramus maritimus junicolus',
#   'Ammodramus maritimus junicolus',
#   'Ammodramus maritimus junicola',
#   'Ammodramus maritimus peninsulae',
#   'http://services.itis.gov/?q=tsn:730157',
#   'http://services.itis.gov/?q=tsn:202315'],
#  [2005,
#   'Ammodramus nelsonii',
#   'Ammodramus nelsonii',
#   'Ammodramus nelsoni',
#   'Ammodramus nelsoni',
#   'http://services.itis.gov/?q=tsn:554031',
#   'http://services.itis.gov/?q=tsn:554031'],
#  [2005,
#   'Ammodytes hexapturus',
#   'Ammodytes hexapturus',
#   'Ammodytes hexapterus',
#   'Ammodytes hexapterus',
#   'http://services.itis.gov/?q=tsn:171672',
#   'http://services.itis.gov/?q=tsn:171672'],
#  [2005,
#   'Ammonitella yatesi',
#   'Ammonitella yatesi',
#   '',
#   'Ammonitella yatesii',
#   'http://services.itis.gov/?q=tsn:77417',
#   'http://services.itis.gov/?q=tsn:77417'],
#  [2005,
#   'Ammophila champlainensis',
#   'Ammophila champlainensis',
#   '',
#   'Ammophila breviligulata ssp. champlainensis',
#   'http://services.itis.gov/?q=tsn:185263',
#   'http://services.itis.gov/?q=tsn:798160'],
#  [2005,
#   'Amnicola sp.',
#   'Amnicola',
#   '',
#   'Amnicola',
#   'http://services.itis.gov/?q=tsn:70747',
#   'http://services.itis.gov/?q=tsn:70747'],
#  [2005,
#   'Amnicola (Lyogyrus) grana',
#   'Amnicola granum',
#   '',
#   'Amnicola granum',
#   'http://services.itis.gov/?q=tsn:70772',
#   'http://services.itis.gov/?q=tsn:70772'],
#  [2005,
#   'Amnicola stygia',
#   'Amnicola stygia',
#   'Amnicola stygius',
#   'Amnicola stygius',
#   'http://services.itis.gov/?q=tsn:70777',
#   'http://services.itis.gov/?q=tsn:70777'],
#  [2005,
#   'Amnicola (Lyogyrus) walkeri',
#   'Amnicola walkeri',
#   '',
#   'Amnicola walkeri',
#   'http://services.itis.gov/?q=tsn:70751',
#   'http://services.itis.gov/?q=tsn:70751'],
#  [2005,
#   'Amorpha herbacea var. floridana',
#   'Amorpha herbacea var. floridana',
#   '',
#   'Amorpha herbacea var. herbacea',
#   'http://services.itis.gov/?q=tsn:532103',
#   'http://services.itis.gov/?q=tsn:182062'],
#  [2005,
#   'Quadrula aurea',
#   'Quadrula aurea',
#   '',
#   'Amphinaias aurea',
#   'http://services.itis.gov/?q=tsn:80066',
#   'http://services.itis.gov/?q=tsn:983630'],
#  [2005,
#   'Quadrula couchiana',
#   'Quadrula couchiana',
#   '',
#   'Amphinaias couchiana',
#   'http://services.itis.gov/?q=tsn:80077',
#   'http://services.itis.gov/?q=tsn:983632'],
#  [2005,
#   'Quadrula houstonensis',
#   'Quadrula houstonensis',
#   '',
#   'Amphinaias houstonensis',
#   'http://services.itis.gov/?q=tsn:80078',
#   'http://services.itis.gov/?q=tsn:983629'],
#  [2005,
#   'Quadrula infucata',
#   'Quadrula infucata',
#   '',
#   'Amphinaias infucata',
#   'http://services.itis.gov/?q=tsn:906936',
#   'http://services.itis.gov/?q=tsn:983628'],
#  [2005,
#   'Quadrula infucata',
#   'Quadrula infucata',
#   '',
#   'Amphinaias infucata',
#   'http://services.itis.gov/?q=tsn:906936',
#   'http://services.itis.gov/?q=tsn:983628'],
#  [2005,
#   'Quadrula kleiniana',
#   'Quadrula kleiniana',
#   '',
#   'Amphinaias kleiniana',
#   'http://services.itis.gov/?q=tsn:906938',
#   'http://services.itis.gov/?q=tsn:983860'],
#  [2005,
#   'Quincuncina kleiniana',
#   'Quincuncina kleiniana',
#   '',
#   'Amphinaias kleiniana',
#   'http://services.itis.gov/?q=tsn:906939',
#   'http://services.itis.gov/?q=tsn:983860'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula nodulata',
#   'Quadrula nodulata',
#   '',
#   'Amphinaias nodulata',
#   'http://services.itis.gov/?q=tsn:80072',
#   'http://services.itis.gov/?q=tsn:983601'],
#  [2005,
#   'Quadrula petrina',
#   'Quadrula petrina',
#   '',
#   'Amphinaias petrina',
#   'http://services.itis.gov/?q=tsn:80079',
#   'http://services.itis.gov/?q=tsn:983775'],
#  [2005,
#   'Quadrula pustulosa',
#   'Quadrula pustulosa',
#   '',
#   'Amphinaias pustulosa',
#   'http://services.itis.gov/?q=tsn:80062',
#   'http://services.itis.gov/?q=tsn:984078'],
#  [2005,
#   'Quadrula pustulosa',
#   'Quadrula pustulosa',
#   '',
#   'Amphinaias pustulosa',
#   'http://services.itis.gov/?q=tsn:80062',
#   'http://services.itis.gov/?q=tsn:984078'],
#  [2005,
#   'Quadrula pustulosa',
#   'Quadrula pustulosa',
#   '',
#   'Amphinaias pustulosa',
#   'http://services.itis.gov/?q=tsn:80062',
#   'http://services.itis.gov/?q=tsn:984078'],
#  [2005,
#   'Quadrula pustulosa',
#   'Quadrula pustulosa',
#   '',
#   'Amphinaias pustulosa',
#   'http://services.itis.gov/?q=tsn:80062',
#   'http://services.itis.gov/?q=tsn:984078'],
#  [2005,
#   'Quadrula pustulosa pustulosa',
#   'Quadrula pustulosa pustulosa',
#   '',
#   'Amphinaias pustulosa',
#   'http://services.itis.gov/?q=tsn:80063',
#   'http://services.itis.gov/?q=tsn:984078'],
#  [2005,
#   'Amphioplus abditus',
#   'Amphioplus abditus',
#   'Amphioplus abdita',
#   'Amphioplus abdita',
#   'http://services.itis.gov/?q=tsn:157709',
#   'http://services.itis.gov/?q=tsn:157709'],
#  [2005,
#   'Axiognathus squamatus',
#   'Axiognathus squamatus',
#   '',
#   'Amphipholis squamata',
#   'http://services.itis.gov/?q=tsn:157678',
#   'http://services.itis.gov/?q=tsn:157676'],
#  [2005,
#   'Amphisbaenia fenestrata',
#   'Amphisbaenia fenestrata',
#   'Amphisbaena fenestrata',
#   'Amphisbaena fenestrata',
#   'http://services.itis.gov/?q=tsn:209631',
#   'http://services.itis.gov/?q=tsn:209631'],
#  [2005,
#   'Aimophila quinquestriata',
#   'Aimophila quinquestriata',
#   '',
#   'Amphispiza quinquestriata',
#   'http://services.itis.gov/?q=tsn:554030',
#   'http://services.itis.gov/?q=tsn:179408'],
#  [2005,
#   'Amsonia ciliata var. filifolia',
#   'Amsonia ciliata var. filifolia',
#   '',
#   'Amsonia ciliata var. tenuifolia',
#   'http://services.itis.gov/?q=tsn:184761',
#   'http://services.itis.gov/?q=tsn:182203'],
#  [2005,
#   'Anacropora sp.',
#   'Anacropora',
#   '',
#   'Anacropora',
#   'http://services.itis.gov/?q=tsn:52990',
#   'http://services.itis.gov/?q=tsn:52990'],
#  [2005,
#   'Anas cyanpotera',
#   'Anas cyanpotera',
#   'Anas cyanoptera',
#   'Anas cyanoptera',
#   'http://services.itis.gov/?q=tsn:175089',
#   'http://services.itis.gov/?q=tsn:175089'],
#  [2005,
#   'Anastrophyllum saxicolus',
#   'Anastrophyllum saxicolus',
#   'Anastrophyllum saxicola',
#   'Anastrophyllum saxicola',
#   'http://services.itis.gov/?q=tsn:14865',
#   'http://services.itis.gov/?q=tsn:14865'],
#  [2005,
#   'Bufo americanus',
#   'Bufo americanus',
#   '',
#   'Anaxyrus americanus americanus',
#   'http://services.itis.gov/?q=tsn:173473',
#   'http://services.itis.gov/?q=tsn:776684'],
#  [2005,
#   'Bufo americanus',
#   'Bufo americanus',
#   '',
#   'Anaxyrus americanus americanus',
#   'http://services.itis.gov/?q=tsn:173473',
#   'http://services.itis.gov/?q=tsn:776684'],
#  [2005,
#   'Bufo americanus',
#   'Bufo americanus',
#   '',
#   'Anaxyrus americanus americanus',
#   'http://services.itis.gov/?q=tsn:173473',
#   'http://services.itis.gov/?q=tsn:776684'],
#  [2005,
#   'Bufo baxteri',
#   'Bufo baxteri',
#   '',
#   'Anaxyrus baxteri',
#   'http://services.itis.gov/?q=tsn:550395',
#   'http://services.itis.gov/?q=tsn:773512'],
#  [2005,
#   'Bufo boreas',
#   'Bufo boreas',
#   '',
#   'Anaxyrus boreas',
#   'http://services.itis.gov/?q=tsn:173482',
#   'http://services.itis.gov/?q=tsn:773513'],
#  [2005,
#   'Bufo boreas',
#   'Bufo boreas',
#   '',
#   'Anaxyrus boreas',
#   'http://services.itis.gov/?q=tsn:173482',
#   'http://services.itis.gov/?q=tsn:773513'],
#  [2005,
#   'Bufo boreas',
#   'Bufo boreas',
#   '',
#   'Anaxyrus boreas',
#   'http://services.itis.gov/?q=tsn:173482',
#   'http://services.itis.gov/?q=tsn:773513'],
#  [2005,
#   'Bufo boreas',
#   'Bufo boreas',
#   '',
#   'Anaxyrus boreas',
#   'http://services.itis.gov/?q=tsn:173482',
#   'http://services.itis.gov/?q=tsn:773513'],
#  [2005,
#   'Bufo boreas',
#   'Bufo boreas',
#   '',
#   'Anaxyrus boreas',
#   'http://services.itis.gov/?q=tsn:173482',
#   'http://services.itis.gov/?q=tsn:773513'],
#  [2005,
#   'Bufo boreas boreas',
#   'Bufo boreas boreas',
#   '',
#   'Anaxyrus boreas boreas',
#   'http://services.itis.gov/?q=tsn:207127',
#   'http://services.itis.gov/?q=tsn:776686'],
#  [2005,
#   'Bufo boreas boreas',
#   'Bufo boreas boreas',
#   '',
#   'Anaxyrus boreas boreas',
#   'http://services.itis.gov/?q=tsn:207127',
#   'http://services.itis.gov/?q=tsn:776686'],
#  [2005,
#   'Bufo boreas boreas',
#   'Bufo boreas boreas',
#   '',
#   'Anaxyrus boreas boreas',
#   'http://services.itis.gov/?q=tsn:207127',
#   'http://services.itis.gov/?q=tsn:776686'],
#  [2005,
#   'Bufo californicus',
#   'Bufo californicus',
#   '',
#   'Anaxyrus californicus',
#   'http://services.itis.gov/?q=tsn:550235',
#   'http://services.itis.gov/?q=tsn:773514'],
#  [2005,
#   'Bufo canorus',
#   'Bufo canorus',
#   '',
#   'Anaxyrus canorus',
#   'http://services.itis.gov/?q=tsn:173483',
#   'http://services.itis.gov/?q=tsn:773515'],
#  [2005,
#   'Bufo cognatus',
#   'Bufo cognatus',
#   '',
#   'Anaxyrus cognatus',
#   'http://services.itis.gov/?q=tsn:173484',
#   'http://services.itis.gov/?q=tsn:773516'],
#  [2005,
#   'Bufo cognatus',
#   'Bufo cognatus',
#   '',
#   'Anaxyrus cognatus',
#   'http://services.itis.gov/?q=tsn:173484',
#   'http://services.itis.gov/?q=tsn:773516'],
#  [2005,
#   'Bufo cognatus',
#   'Bufo cognatus',
#   '',
#   'Anaxyrus cognatus',
#   'http://services.itis.gov/?q=tsn:173484',
#   'http://services.itis.gov/?q=tsn:773516'],
#  [2005,
#   'Bufo cognatus',
#   'Bufo cognatus',
#   '',
#   'Anaxyrus cognatus',
#   'http://services.itis.gov/?q=tsn:173484',
#   'http://services.itis.gov/?q=tsn:773516'],
#  [2005,
#   'Bufo cognatus',
#   'Bufo cognatus',
#   '',
#   'Anaxyrus cognatus',
#   'http://services.itis.gov/?q=tsn:173484',
#   'http://services.itis.gov/?q=tsn:773516'],
#  [2005,
#   'Bufo debilis',
#   'Bufo debilis',
#   '',
#   'Anaxyrus debilis debilis',
#   'http://services.itis.gov/?q=tsn:173485',
#   'http://services.itis.gov/?q=tsn:776690'],
#  [2005,
#   'Bufo debilis',
#   'Bufo debilis',
#   '',
#   'Anaxyrus debilis debilis',
#   'http://services.itis.gov/?q=tsn:173485',
#   'http://services.itis.gov/?q=tsn:776690'],
#  [2005,
#   'Bufo exsul',
#   'Bufo exsul',
#   '',
#   'Anaxyrus exsul',
#   'http://services.itis.gov/?q=tsn:173486',
#   'http://services.itis.gov/?q=tsn:773519'],
#  [2005,
#   'Bufo fowleri formerly Bufo woodhousii fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo woodhousii fowleri',
#   'Bufo woodhousii fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173477',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo woodhousii fowleri',
#   'Bufo woodhousii fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173477',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo fowleri',
#   'Bufo fowleri',
#   '',
#   'Anaxyrus fowleri',
#   'http://services.itis.gov/?q=tsn:173478',
#   'http://services.itis.gov/?q=tsn:773520'],
#  [2005,
#   'Bufo hemiophrys',
#   'Bufo hemiophrys',
#   '',
#   'Anaxyrus hemiophrys',
#   'http://services.itis.gov/?q=tsn:173487',
#   'http://services.itis.gov/?q=tsn:773521'],
#  [2005,
#   'Bufo houstonensis',
#   'Bufo houstonensis',
#   '',
#   'Anaxyrus houstonensis',
#   'http://services.itis.gov/?q=tsn:173488',
#   'http://services.itis.gov/?q=tsn:773522'],
#  [2005,
#   'Bufo microscaphus',
#   'Bufo microscaphus',
#   '',
#   'Anaxyrus microscaphus',
#   'http://services.itis.gov/?q=tsn:173490',
#   'http://services.itis.gov/?q=tsn:773525'],
#  [2005,
#   'Bufo microscaphus',
#   'Bufo microscaphus',
#   '',
#   'Anaxyrus microscaphus',
#   'http://services.itis.gov/?q=tsn:173490',
#   'http://services.itis.gov/?q=tsn:773525'],
#  [2005,
#   'Bufo microscaphus',
#   'Bufo microscaphus',
#   '',
#   'Anaxyrus microscaphus',
#   'http://services.itis.gov/?q=tsn:173490',
#   'http://services.itis.gov/?q=tsn:773525'],
#  [2005,
#   'Bufo microscaphus microscaphus',
#   'Bufo microscaphus microscaphus',
#   '',
#   'Anaxyrus microscaphus',
#   'http://services.itis.gov/?q=tsn:207135',
#   'http://services.itis.gov/?q=tsn:773525'],
#  [2005,
#   'Bufo nelsoni',
#   'Bufo nelsoni',
#   '',
#   'Anaxyrus nelsoni',
#   'http://services.itis.gov/?q=tsn:550236',
#   'http://services.itis.gov/?q=tsn:773526'],
#  [2005,
#   'Bufo punctatus',
#   'Bufo punctatus',
#   '',
#   'Anaxyrus punctatus',
#   'http://services.itis.gov/?q=tsn:173491',
#   'http://services.itis.gov/?q=tsn:773527'],
#  [2005,
#   'Bufo quercicus',
#   'Bufo quercicus',
#   '',
#   'Anaxyrus quercicus',
#   'http://services.itis.gov/?q=tsn:173479',
#   'http://services.itis.gov/?q=tsn:773528'],
#  [2005,
#   'Bufo quercicus',
#   'Bufo quercicus',
#   '',
#   'Anaxyrus quercicus',
#   'http://services.itis.gov/?q=tsn:173479',
#   'http://services.itis.gov/?q=tsn:773528'],
#  [2005,
#   'Bufo quercicus',
#   'Bufo quercicus',
#   '',
#   'Anaxyrus quercicus',
#   'http://services.itis.gov/?q=tsn:173479',
#   'http://services.itis.gov/?q=tsn:773528'],
#  [2005,
#   'Bufo woodhousii',
#   'Bufo woodhousii',
#   '',
#   'Anaxyrus woodhousii woodhousii',
#   'http://services.itis.gov/?q=tsn:173476',
#   'http://services.itis.gov/?q=tsn:776698'],
#  [2005,
#   'Bufo woodhousii',
#   'Bufo woodhousii',
#   '',
#   'Anaxyrus woodhousii woodhousii',
#   'http://services.itis.gov/?q=tsn:173476',
#   'http://services.itis.gov/?q=tsn:776698'],
#  [2005,
#   'Ancylopsetta quadrocellata',
#   'Ancylopsetta quadrocellata',
#   '',
#   'Ancylopsetta ommata',
#   'http://services.itis.gov/?q=tsn:172757',
#   'http://services.itis.gov/?q=tsn:616601'],
#  [2005,
#   'Andrena (Scrapteropsis) flaminea (LaBerge)',
#   'Andrena flaminea',
#   '',
#   'Andrena flaminea',
#   'http://services.itis.gov/?q=tsn:654282',
#   'http://services.itis.gov/?q=tsn:654282'],
#  [2005,
#   'Andrena (Micrandrena) micheneri (Ribble)',
#   'Andrena micheneri',
#   '',
#   'Andrena micheneri',
#   'http://services.itis.gov/?q=tsn:654385',
#   'http://services.itis.gov/?q=tsn:654385'],
#  [2005,
#   'Andrena (Tylandrena) scotoptera (Cockerell)',
#   'Andrena scotoptera',
#   '',
#   'Andrena scotoptera',
#   'http://services.itis.gov/?q=tsn:752905',
#   'http://services.itis.gov/?q=tsn:752905'],
#  [2005,
#   'Anguilla Rostrata',
#   'Anguilla Rostrata',
#   '',
#   'Anguilla rostrata',
#   'http://services.itis.gov/?q=tsn:161127',
#   'http://services.itis.gov/?q=tsn:161127'],
#  [2005,
#   'Anillinus sp.',
#   'Anillinus',
#   '',
#   'Anillinus',
#   'http://services.itis.gov/?q=tsn:109762',
#   'http://services.itis.gov/?q=tsn:109762'],
#  [2005,
#   'Ankyrodrilus legacus',
#   'Ankyrodrilus legacus',
#   'Ankyrodrilus legaeus',
#   'Ankyrodrilus legaeus',
#   'http://services.itis.gov/?q=tsn:980449',
#   'http://services.itis.gov/?q=tsn:980449'],
#  [2005,
#   'Anniella pulchra pulchra',
#   'Anniella pulchra pulchra',
#   '',
#   'Anniella pulchra',
#   'http://services.itis.gov/?q=tsn:914119',
#   'http://services.itis.gov/?q=tsn:174095'],
#  [2005,
#   'Anniella pulchra nigra',
#   'Anniella pulchra nigra',
#   '',
#   'Anniella pulchra',
#   'http://services.itis.gov/?q=tsn:208998',
#   'http://services.itis.gov/?q=tsn:174095'],
#  [2005,
#   'Anodonta wahlametensis',
#   'Anodonta wahlametensis',
#   '',
#   'Anodonta nuttalliana',
#   'http://services.itis.gov/?q=tsn:906940',
#   'http://services.itis.gov/?q=tsn:79943'],
#  [2005,
#   'Anodontoides denigratus',
#   'Anodontoides denigratus',
#   '',
#   'Anodontoides ferussacianus',
#   'http://services.itis.gov/?q=tsn:906928',
#   'http://services.itis.gov/?q=tsn:80148'],
#  [2005,
#   'Anser albifrons gambelli',
#   'Anser albifrons gambelli',
#   '',
#   'Anser albifrons gambeli',
#   'http://services.itis.gov/?q=tsn:175022',
#   'http://services.itis.gov/?q=tsn:714773'],
#  [2005,
#   'Antecardina lauensis',
#   'Antecardina lauensis',
#   'Antecaridina lauensis',
#   'Antecaridina lauensis',
#   'http://services.itis.gov/?q=tsn:659853',
#   'http://services.itis.gov/?q=tsn:659853'],
#  [2005,
#   'Antennarius commersoni',
#   'Antennarius commersoni',
#   '',
#   'Antennarius commerson',
#   'http://services.itis.gov/?q=tsn:164544',
#   'http://services.itis.gov/?q=tsn:690357'],
#  [2005,
#   'Anthophorula (Anthophorisca) ignota (Timberlake',
#   'Anthophorula ignota',
#   '',
#   'Anthophorula ignota',
#   'http://services.itis.gov/?q=tsn:698974',
#   'http://services.itis.gov/?q=tsn:698974'],
#  [2005,
#   'Potamanthus walkeri',
#   'Potamanthus walkeri',
#   '',
#   'Anthopotamus verticis',
#   'http://services.itis.gov/?q=tsn:101521',
#   'http://services.itis.gov/?q=tsn:609662'],
#  [2005,
#   'Hierochloe alpina',
#   'Hierochloe alpina',
#   '',
#   'Anthoxanthum monticola',
#   'http://services.itis.gov/?q=tsn:40853',
#   'http://services.itis.gov/?q=tsn:508922'],
#  [2005,
#   'Anthrobia mammouthia',
#   'Anthrobia mammouthia',
#   'Anthrobia monmouthia',
#   'Anthrobia monmouthia',
#   'http://services.itis.gov/?q=tsn:851025',
#   'http://services.itis.gov/?q=tsn:851025'],
#  [2005,
#   'Antroselatus spiralis',
#   'Antroselatus spiralis',
#   '',
#   'Antroselates spiralis',
#   'http://services.itis.gov/?q=tsn:70673',
#   'http://services.itis.gov/?q=tsn:567237'],
#  [2005,
#   'Apalone spiniferus',
#   'Apalone spiniferus',
#   'Apalone spinifera',
#   'Apalone spinifera',
#   'http://services.itis.gov/?q=tsn:208680',
#   'http://services.itis.gov/?q=tsn:208680'],
#  [2005,
#   'Trionyx spiniferus',
#   'Trionyx spiniferus',
#   '',
#   'Apalone spinifera',
#   'http://services.itis.gov/?q=tsn:173850',
#   'http://services.itis.gov/?q=tsn:208680'],
#  [2005,
#   'Apalone spinifera hartwegi',
#   'Apalone spinifera hartwegi',
#   '',
#   'Apalone spinifera spinifera',
#   'http://services.itis.gov/?q=tsn:208689',
#   'http://services.itis.gov/?q=tsn:208693'],
#  [2005,
#   'Apainea lutosa',
#   'Apainea lutosa',
#   'Apamea lutosa',
#   'Apamea lutosa',
#   'http://services.itis.gov/?q=tsn:937842',
#   'http://services.itis.gov/?q=tsn:937842'],
#  [2005,
#   'Apamea (Agroperina) lutosa',
#   'Apamea lutosa',
#   '',
#   'Apamea lutosa',
#   'http://services.itis.gov/?q=tsn:937842',
#   'http://services.itis.gov/?q=tsn:937842'],
#  [2005,
#   'Apamea (Crymodes) relicina',
#   'Apamea relicina',
#   '',
#   'Apamea relicina',
#   'http://services.itis.gov/?q=tsn:937851',
#   'http://services.itis.gov/?q=tsn:937851'],
#  [2005,
#   'Apeltes quadricus',
#   'Apeltes quadricus',
#   'Apeltes quadracus',
#   'Apeltes quadracus',
#   'http://services.itis.gov/?q=tsn:166397',
#   'http://services.itis.gov/?q=tsn:166397'],
#  [2005,
#   'Apenes sp. UASM 11',
#   'Apenes',
#   '',
#   'Apenes',
#   'http://services.itis.gov/?q=tsn:111561',
#   'http://services.itis.gov/?q=tsn:111561'],
#  [2005,
#   'Aphareus rutlians',
#   'Aphareus rutlians',
#   'Aphareus rutilans',
#   'Aphareus rutilans',
#   'http://services.itis.gov/?q=tsn:168929',
#   'http://services.itis.gov/?q=tsn:168929'],
#  [2005,
#   'Aphelochaeta sp.',
#   'Aphelochaeta',
#   '',
#   'Aphelochaeta',
#   'http://services.itis.gov/?q=tsn:573719',
#   'http://services.itis.gov/?q=tsn:573719'],
#  [2005,
#   'Aphroderus sayanus',
#   'Aphroderus sayanus',
#   'Aphredoderus sayanus',
#   'Aphredoderus sayanus',
#   'http://services.itis.gov/?q=tsn:164405',
#   'http://services.itis.gov/?q=tsn:164405'],
#  [2005,
#   'Aplidium sp.',
#   'Aplidium',
#   '',
#   'Aplidium',
#   'http://services.itis.gov/?q=tsn:159038',
#   'http://services.itis.gov/?q=tsn:159038'],
#  [2005,
#   'Apldium spp.',
#   'Apldium',
#   'Aplidium',
#   'Aplidium',
#   'http://services.itis.gov/?q=tsn:158940',
#   'http://services.itis.gov/?q=tsn:159038'],
#  [2005,
#   'Aplonis tabuensis manuae/tutuilae',
#   'Aplonis tabuensis',
#   '',
#   'Aplonis tabuensis',
#   'http://services.itis.gov/?q=tsn:554134',
#   'http://services.itis.gov/?q=tsn:554134'],
#  [2005,
#   'Apochthonius hobb',
#   'Apochthonius hobb',
#   '',
#   'Apochthonius hobbsi',
#   'http://services.itis.gov/?q=tsn:746914',
#   'http://services.itis.gov/?q=tsn:746914'],
#  [2005,
#   'Prionospio dayi',
#   'Prionospio dayi',
#   '',
#   'Apoprionospio dayi',
#   'http://services.itis.gov/?q=tsn:67025',
#   'http://services.itis.gov/?q=tsn:67024'],
#  [2005,
#   'Appaleptoneta sp.',
#   'Appaleptoneta',
#   '',
#   'Appaleptoneta',
#   'http://services.itis.gov/?q=tsn:847894',
#   'http://services.itis.gov/?q=tsn:847894'],
#  [2005,
#   'Appaleptoneta sp. 1',
#   'Appaleptoneta',
#   '',
#   'Appaleptoneta',
#   'http://services.itis.gov/?q=tsn:847894',
#   'http://services.itis.gov/?q=tsn:847894'],
#  [2005,
#   'Apteromechus texanus (Fall)',
#   'Apteromechus texanus',
#   '',
#   'Apteromechus texanus',
#   'http://services.itis.gov/?q=tsn:617458',
#   'http://services.itis.gov/?q=tsn:617458'],
#  [2005,
#   'Arabis lyrata',
#   'Arabis lyrata',
#   '',
#   'Arabidopsis lyrata ssp. lyrata',
#   'http://services.itis.gov/?q=tsn:22672',
#   'http://services.itis.gov/?q=tsn:823323'],
#  [2005,
#   'Arabis macdonaldiana',
#   'Arabis macdonaldiana',
#   '',
#   'Arabis mcdonaldiana',
#   'http://services.itis.gov/?q=tsn:22710',
#   'http://services.itis.gov/?q=tsn:823056'],
#  [2005,
#   'Archeolarca guadalupensis (Muchmore)',
#   'Archeolarca guadalupensis',
#   '',
#   'Archeolarca guadalupensis',
#   'http://services.itis.gov/?q=tsn:749265',
#   'http://services.itis.gov/?q=tsn:749265'],
#  [2005,
#   'Arkansia wheeleri',
#   'Arkansia wheeleri',
#   '',
#   'Arcidens wheeleri',
#   'http://services.itis.gov/?q=tsn:80241',
#   'http://services.itis.gov/?q=tsn:198390'],
#  [2005,
#   'Arkansia wheeleri',
#   'Arkansia wheeleri',
#   '',
#   'Arcidens wheeleri',
#   'http://services.itis.gov/?q=tsn:80241',
#   'http://services.itis.gov/?q=tsn:198390'],
#  [2005,
#   'Arkansia wheeleri',
#   'Arkansia wheeleri',
#   '',
#   'Arcidens wheeleri',
#   'http://services.itis.gov/?q=tsn:80241',
#   'http://services.itis.gov/?q=tsn:198390'],
#  [2005,
#   'Casmerodius albus',
#   'Casmerodius albus',
#   '',
#   'Ardea alba',
#   'http://services.itis.gov/?q=tsn:174810',
#   'http://services.itis.gov/?q=tsn:554135'],
#  [2005,
#   'Casmerodius albus',
#   'Casmerodius albus',
#   '',
#   'Ardea alba',
#   'http://services.itis.gov/?q=tsn:174810',
#   'http://services.itis.gov/?q=tsn:554135'],
#  [2005,
#   'Glossodoris poliahu',
#   'Glossodoris poliahu',
#   '',
#   'Ardeadoris poliahu',
#   'http://www.marinespecies.org/aphia.php?p=taxdetails&id=559957',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/597323'],
#  [2005,
#   'Ardea Herodias',
#   'Ardea Herodias',
#   '',
#   'Ardea herodias',
#   'http://services.itis.gov/?q=tsn:174773',
#   'http://services.itis.gov/?q=tsn:174773'],
#  [2005,
#   'Argyroxiphium sandwicense subsp. macrocephalum',
#   'Argyroxiphium sandwicense ssp. macrocephalum',
#   '',
#   'Argyroxiphium sandwicense ssp. macrocephalum',
#   'http://services.itis.gov/?q=tsn:185198',
#   'http://services.itis.gov/?q=tsn:185198'],
#  [2005,
#   'Argyroxiphium sandwicense subsp. sandwicense',
#   'Argyroxiphium sandwicense ssp. sandwicense',
#   '',
#   'Argyroxiphium sandwicense ssp. sandwicense',
#   'http://services.itis.gov/?q=tsn:185197',
#   'http://services.itis.gov/?q=tsn:185197'],
#  [2005,
#   'Gomphus villosipes',
#   'Gomphus villosipes',
#   '',
#   'Arigomphus villosipes',
#   'http://services.itis.gov/?q=tsn:101698',
#   'http://services.itis.gov/?q=tsn:101776'],
#  [2005,
#   'Arius felis',
#   'Arius felis',
#   '',
#   'Ariopsis felis',
#   'http://services.itis.gov/?q=tsn:164165',
#   'http://services.itis.gov/?q=tsn:680665'],
#  [2005,
#   'Sesarma benedicti',
#   'Sesarma benedicti',
#   '',
#   'Armases benedicti',
#   'http://services.itis.gov/?q=tsn:99041',
#   'http://services.itis.gov/?q=tsn:660770'],
#  [2005,
#   'Gyraulus crista',
#   'Gyraulus crista',
#   '',
#   'Armiger crista',
#   'http://services.itis.gov/?q=tsn:76597',
#   'http://services.itis.gov/?q=tsn:76619'],
#  [2005,
#   'Gyraulus crista',
#   'Gyraulus crista',
#   '',
#   'Armiger crista',
#   'http://services.itis.gov/?q=tsn:76597',
#   'http://services.itis.gov/?q=tsn:76619'],
#  [2005,
#   'Gyraulus crista',
#   'Gyraulus crista',
#   '',
#   'Armiger crista',
#   'http://services.itis.gov/?q=tsn:76597',
#   'http://services.itis.gov/?q=tsn:76619'],
#  [2005,
#   'Arrhopalites sp 2',
#   'Arrhopalites',
#   '',
#   'Arrhopalites',
#   'http://services.itis.gov/?q=tsn:100443',
#   'http://services.itis.gov/?q=tsn:100443'],
#  [2005,
#   'Arrhopalites sp 3',
#   'Arrhopalites',
#   '',
#   'Arrhopalites',
#   'http://services.itis.gov/?q=tsn:100443',
#   'http://services.itis.gov/?q=tsn:100443'],
#  [2005,
#   'Arrhopalites sp 1',
#   'Arrhopalites',
#   '',
#   'Arrhopalites',
#   'http://services.itis.gov/?q=tsn:100443',
#   'http://services.itis.gov/?q=tsn:100443'],
#  [2005,
#   'Arrhopalites sp.',
#   'Arrhopalites',
#   '',
#   'Arrhopalites',
#   'http://services.itis.gov/?q=tsn:100443',
#   'http://services.itis.gov/?q=tsn:100443'],
#  [2005,
#   'Arrhopalites caedus',
#   'Arrhopalites caedus',
#   'Arrhopalites caecus',
#   'Arrhopalites caecus',
#   'http://services.itis.gov/?q=tsn:100446',
#   'http://services.itis.gov/?q=tsn:100446'],
#  [2005,
#   'Artemisia campestris var. wormskioldii',
#   'Artemisia campestris var. wormskioldii',
#   '',
#   'Artemisia campestris ssp. pacifica',
#   'http://services.itis.gov/?q=tsn:566593',
#   'http://services.itis.gov/?q=tsn:183751'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli',
#   'Amphispiza belli',
#   '',
#   'Artemisiospiza belli',
#   'http://services.itis.gov/?q=tsn:179402',
#   'http://services.itis.gov/?q=tsn:997724'],
#  [2005,
#   'Amphispiza belli belli',
#   'Amphispiza belli belli',
#   '',
#   'Artemisiospiza belli belli',
#   'http://services.itis.gov/?q=tsn:179405',
#   'http://services.itis.gov/?q=tsn:998052'],
#  [2005,
#   'Amphispiza belli clementeae',
#   'Amphispiza belli clementeae',
#   '',
#   'Artemisiospiza belli clementeae',
#   'http://services.itis.gov/?q=tsn:179406',
#   'http://services.itis.gov/?q=tsn:998053'],
#  [2005,
#   'Asabellides sp. A',
#   'Asabellides',
#   '',
#   'Asabellides',
#   'http://services.itis.gov/?q=tsn:67784',
#   'http://services.itis.gov/?q=tsn:67784'],
#  [2005,
#   'Asclepias asperula var. decumbens',
#   'Asclepias asperula var. decumbens',
#   '',
#   'Asclepias asperula ssp. capricornu',
#   'http://services.itis.gov/?q=tsn:532380',
#   'http://services.itis.gov/?q=tsn:30249'],
#  [2005,
#   'Diellia erecta',
#   'Diellia erecta',
#   '',
#   'Asplenium dielerectum',
#   'http://services.itis.gov/?q=tsn:17496',
#   'http://services.itis.gov/?q=tsn:897121'],
#  [2005,
#   'Diellia falcata',
#   'Diellia falcata',
#   '',
#   'Asplenium dielfalcatum',
#   'http://services.itis.gov/?q=tsn:17497',
#   'http://services.itis.gov/?q=tsn:897132'],
#  [2005,
#   'Diellia mannii',
#   'Diellia mannii',
#   '',
#   'Asplenium dielmannii',
#   'http://services.itis.gov/?q=tsn:17499',
#   'http://services.itis.gov/?q=tsn:897130'],
#  [2005,
#   'Diellia pallida',
#   'Diellia pallida',
#   '',
#   'Asplenium dielpallidum',
#   'http://services.itis.gov/?q=tsn:507516',
#   'http://services.itis.gov/?q=tsn:897136'],
#  [2005,
#   'Diellia unisora',
#   'Diellia unisora',
#   '',
#   'Asplenium unisorum',
#   'http://services.itis.gov/?q=tsn:17500',
#   'http://services.itis.gov/?q=tsn:897129'],
#  [2005,
#   'Asplenium heteroresiliens',
#   'Asplenium heteroresiliens',
#   'Asplenium X heteroresiliens',
#   'Asplenium X heteroresiliens',
#   'http://services.itis.gov/?q=tsn:17347',
#   'http://services.itis.gov/?q=tsn:17347'],
#  [2005,
#   'Asterias spp.',
#   'Asterias',
#   '',
#   'Asterias',
#   'http://services.itis.gov/?q=tsn:157215',
#   'http://services.itis.gov/?q=tsn:157215'],
#  [2005,
#   'Asterias forbesii',
#   'Asterias forbesii',
#   'Asterias forbesi',
#   'Asterias forbesi',
#   'http://services.itis.gov/?q=tsn:157217',
#   'http://services.itis.gov/?q=tsn:157217'],
#  [2005,
#   'Asteriid spp.',
#   'Asteriid',
#   '',
#   'Asteriidae',
#   'http://www.marinespecies.org/aphia.php?p=taxdetails&id=123121',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/123121'],
#  [2005,
#   'Astragalus sterilis',
#   'Astragalus sterilis',
#   '',
#   'Astragalus cusickii var. sterilis',
#   'http://services.itis.gov/?q=tsn:25689',
#   'http://services.itis.gov/?q=tsn:192448'],
#  [2005,
#   'Astragalus diaphanus var. diurnus',
#   'Astragalus diaphanus var. diurnus',
#   '',
#   'Astragalus diaphanus',
#   'http://services.itis.gov/?q=tsn:192458',
#   'http://services.itis.gov/?q=tsn:25494'],
#  [2005,
#   'Ataxia tibialis (Schaeffer)',
#   'Ataxia tibialis',
#   '',
#   'Ataxia tibialis',
#   'http://services.itis.gov/?q=tsn:702512',
#   'http://services.itis.gov/?q=tsn:702512'],
#  [2005,
#   'Speotyto cunicularia',
#   'Speotyto cunicularia',
#   '',
#   'Athene cunicularia',
#   'http://services.itis.gov/?q=tsn:177917',
#   'http://services.itis.gov/?q=tsn:177946'],
#  [2005,
#   'Speotyto cunicularia',
#   'Speotyto cunicularia',
#   '',
#   'Athene cunicularia',
#   'http://services.itis.gov/?q=tsn:177917',
#   'http://services.itis.gov/?q=tsn:177946'],
#  [2005,
#   'Lepisosteus spatula',
#   'Lepisosteus spatula',
#   '',
#   'Atractosteus spatula',
#   'http://services.itis.gov/?q=tsn:161097',
#   'http://services.itis.gov/?q=tsn:201897'],
#  [2005,
#   'Atrichum crispulum',
#   'Atrichum crispulum',
#   'Atrichum crispum',
#   'Atrichum crispum',
#   'http://services.itis.gov/?q=tsn:15785',
#   'http://services.itis.gov/?q=tsn:15785'],
#  [2005,
#   'Atrytonopsis hianna loammi',
#   'Atrytonopsis hianna loammi',
#   '',
#   'Atrytonopsis loammi',
#   'http://services.itis.gov/?q=tsn:779657',
#   'http://services.itis.gov/?q=tsn:706597'],
#  [2005,
#   'Attheyella (Mrazekiella) Illiniosensis',
#   'Attheyella illinoisensis',
#   '',
#   'Attheyella illinoisensis',
#   'http://services.itis.gov/?q=tsn:88234',
#   'http://services.itis.gov/?q=tsn:88234'],
#  [2005,
#   'Attheyella (Canthocamptus) Illiniosensis',
#   'Attheyella illinoisensis',
#   '',
#   'Attheyella illinoisensis',
#   'http://services.itis.gov/?q=tsn:88234',
#   'http://services.itis.gov/?q=tsn:88234'],
#  [2005,
#   'Attheyella (Mrazekiella) Obatogamensis',
#   'Attheyella obatogamensis',
#   '',
#   'Attheyella obatogamensis',
#   'http://services.itis.gov/?q=tsn:88224',
#   'http://services.itis.gov/?q=tsn:88224'],
#  [2005,
#   'Homoptera',
#   'Homoptera',
#   '',
#   'Auchenorrhyncha',
#   'http://services.itis.gov/?q=tsn:109166',
# ...
#   '',
#   'Empidonax traillii',
#   'http://services.itis.gov/?q=tsn:178341',
#   'http://services.itis.gov/?q=tsn:178341'],
#  [2005,
#   'Empidonax trailli extimus',
#   'Empidonax trailli extimus',
#   'Empidonax traillii extimus',
#   'Empidonax traillii extimus',
#   'http://services.itis.gov/?q=tsn:712529',
#   'http://services.itis.gov/?q=tsn:712529'],
#  [2005,
#   'Emys blandingii',
#   'Emys blandingii',
#   '',
#   'Emydoidea blandingii',
#   'http://services.itis.gov/?q=tsn:208630',
#   'http://services.itis.gov/?q=tsn:173789'],
#  [2005,
#   'Emys blandingii',
#   'Emys blandingii',
#   '',
#   'Emydoidea blandingii',
#   'http://services.itis.gov/?q=tsn:208630',
#   'http://services.itis.gov/?q=tsn:173789'],
#  [2005,
#   'Emys blandingii',
#   'Emys blandingii',
#   '',
#   'Emydoidea blandingii',
#   'http://services.itis.gov/?q=tsn:208630',
#   'http://services.itis.gov/?q=tsn:173789'],
#  [2005,
#   'ENALLAGMA CLAUSUM',
#   'ENALLAGMA CLAUSUM',
#   '',
#   'Enallagma clausum',
#   'http://services.itis.gov/?q=tsn:102132',
#   'http://services.itis.gov/?q=tsn:102132'],
#  [2005,
#   'Enallagma cyathigerum vernale',
#   'Enallagma cyathigerum vernale',
#   '',
#   'Enallagma vernale',
#   'http://services.itis.gov/?q=tsn:593408',
#   'http://services.itis.gov/?q=tsn:102131'],
#  [2005,
#   'Enchytraeidae sp. A',
#   'Enchytraeidae',
#   '',
#   'Enchytraeidae',
#   'http://services.itis.gov/?q=tsn:68510',
#   'http://services.itis.gov/?q=tsn:68510'],
#  [2005,
#   'Enneacanthus chatedon',
#   'Enneacanthus chatedon',
#   'Enneacanthus chaetodon',
#   'Enneacanthus chaetodon',
#   'http://services.itis.gov/?q=tsn:168108',
#   'http://services.itis.gov/?q=tsn:168108'],
#  [2005,
#   'Ensatina eschscholtzii croceator',
#   'Ensatina eschscholtzii croceator',
#   'Ensatina eschscholtzii croceater',
#   'Ensatina eschscholtzii croceater',
#   'http://services.itis.gov/?q=tsn:208360',
#   'http://services.itis.gov/?q=tsn:208360'],
#  [2005,
#   'Ensatina klauberi',
#   'Ensatina klauberi',
#   '',
#   'Ensatina eschscholtzii klauberi',
#   'http://services.itis.gov/?q=tsn:208364',
#   'http://services.itis.gov/?q=tsn:208363'],
#  [2005,
#   'Lyonsia (Entodesma) beana',
#   'Entodesma beana',
#   '',
#   'Entodesma beana',
#   'http://services.itis.gov/?q=tsn:81915',
#   'http://services.itis.gov/?q=tsn:81915'],
#  [2005,
#   'Lampetra lethophaga',
#   'Lampetra lethophaga',
#   '',
#   'Entosphenus lethophagus',
#   'http://services.itis.gov/?q=tsn:159710',
#   'http://services.itis.gov/?q=tsn:914060'],
#  [2005,
#   'Lampetra minima',
#   'Lampetra minima',
#   '',
#   'Entosphenus minimus',
#   'http://services.itis.gov/?q=tsn:159711',
#   'http://services.itis.gov/?q=tsn:914063'],
#  [2005,
#   'Lampetra similis',
#   'Lampetra similis',
#   '',
#   'Entosphenus similis',
#   'http://services.itis.gov/?q=tsn:201892',
#   'http://services.itis.gov/?q=tsn:914058'],
#  [2005,
#   'Lampetra tridentata',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata ssp.',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata ssp. 1',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Lampetra tridentata ssp.',
#   'Lampetra tridentata',
#   '',
#   'Entosphenus tridentatus',
#   'http://services.itis.gov/?q=tsn:159713',
#   'http://services.itis.gov/?q=tsn:159699'],
#  [2005,
#   'Entovalva sp. B',
#   'Entovalva',
#   '',
#   'Entovalva',
#   'http://services.itis.gov/?q=tsn:80689',
#   'http://services.itis.gov/?q=tsn:80689'],
#  [2005,
#   'Entovalva sp. A',
#   'Entovalva',
#   '',
#   'Entovalva',
#   'http://services.itis.gov/?q=tsn:80689',
#   'http://services.itis.gov/?q=tsn:80689'],
#  [2005,
#   'Ephemerella lacustris',
#   'Ephemerella lacustris',
#   '',
#   'Ephemerella excrucians',
#   'http://services.itis.gov/?q=tsn:101285',
#   'http://services.itis.gov/?q=tsn:101276'],
#  [2005,
#   'Ephemerella argo',
#   'Ephemerella argo',
#   '',
#   'Ephemerella excrucians',
#   'http://services.itis.gov/?q=tsn:101253',
#   'http://services.itis.gov/?q=tsn:101276'],
#  [2005,
#   'Ephemerella inconstans',
#   'Ephemerella inconstans',
#   '',
#   'Ephemerella invaria',
#   'http://services.itis.gov/?q=tsn:101281',
#   'http://services.itis.gov/?q=tsn:101282'],
#  [2005,
#   'Ephyriades brunneus floridensis',
#   'Ephyriades brunneus floridensis',
#   '',
#   'Ephyriades brunnea floridensis',
#   'http://services.itis.gov/?q=tsn:707384',
#   'http://services.itis.gov/?q=tsn:778312'],
#  [2005,
#   'Epidendrum conopseum',
#   'Epidendrum conopseum',
#   '',
#   'Epidendrum magnoliae',
#   'http://services.itis.gov/?q=tsn:43559',
#   'http://services.itis.gov/?q=tsn:894697'],
#  [2005,
#   'Epitonium ulu',
#   'Epitonium ulu',
#   '',
#   'Epifungium ulu',
#   'http://www.marinespecies.org/aphia.php?p=taxdetails&id=524573',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/523767'],
#  [2005,
#   'Epinephalus drummondhayi',
#   'Epinephalus drummondhayi',
#   'Epinephelus drummondhayi',
#   'Epinephelus drummondhayi',
#   'http://services.itis.gov/?q=tsn:167698',
#   'http://services.itis.gov/?q=tsn:167698'],
#  [2005,
#   'Epinephalus itajara',
#   'Epinephalus itajara',
#   '',
#   'Epinephelus itajara',
#   'http://www.marinespecies.org/aphia.php?p=taxdetails&id=401331',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/159353'],
#  [2005,
#   'Epinephalus itajara',
#   'Epinephalus itajara',
#   '',
#   'Epinephelus itajara',
#   'http://www.marinespecies.org/aphia.php?p=taxdetails&id=401331',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/159353'],
#  [2005,
#   'Epinephalus morio',
#   'Epinephalus morio',
#   'Epinephelus morio',
#   'Epinephelus morio',
#   'http://services.itis.gov/?q=tsn:167702',
#   'http://services.itis.gov/?q=tsn:167702'],
#  [2005,
#   'Epioblasma florentina curtisi',
#   'Epioblasma florentina curtisi',
#   '',
#   'Epioblasma florentina',
#   'http://services.itis.gov/?q=tsn:80313',
#   'http://services.itis.gov/?q=tsn:80310'],
#  [2005,
#   'Epioblasma florentina curtisii',
#   'Epioblasma florentina curtisii',
#   '',
#   'Epioblasma florentina',
#   'http://services.itis.gov/?q=tsn:568489',
#   'http://services.itis.gov/?q=tsn:80310'],
#  [2005,
#   'Epioblasma florentina walkeri',
#   'Epioblasma florentina walkeri',
#   '',
#   'Epioblasma florentina',
#   'http://services.itis.gov/?q=tsn:80314',
#   'http://services.itis.gov/?q=tsn:80310'],
#  [2005,
#   'Epioblasma florentina walkeri',
#   'Epioblasma florentina walkeri',
#   '',
#   'Epioblasma florentina',
#   'http://services.itis.gov/?q=tsn:80314',
#   'http://services.itis.gov/?q=tsn:80310'],
#  [2005,
#   'Epioblasma florentina walkeri',
#   'Epioblasma florentina walkeri',
#   '',
#   'Epioblasma florentina',
#   'http://services.itis.gov/?q=tsn:80314',
#   'http://services.itis.gov/?q=tsn:80310'],
#  [2005,
#   'Epioblasma obliquata obliquata',
#   'Epioblasma obliquata obliquata',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80324',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata perobliqua',
#   'Epioblasma obliquata perobliqua',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80325',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata perobliqua',
#   'Epioblasma obliquata perobliqua',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80325',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata perobliqua',
#   'Epioblasma obliquata perobliqua',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80325',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata obliquata',
#   'Epioblasma obliquata obliquata',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80324',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata obliquata',
#   'Epioblasma obliquata obliquata',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80324',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma obliquata obliquata',
#   'Epioblasma obliquata obliquata',
#   '',
#   'Epioblasma obliquata',
#   'http://services.itis.gov/?q=tsn:80324',
#   'http://services.itis.gov/?q=tsn:80323'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa rangiana',
#   'Epioblasma torulosa rangiana',
#   '',
#   'Epioblasma rangiana',
#   'http://services.itis.gov/?q=tsn:80343',
#   'http://services.itis.gov/?q=tsn:983763'],
#  [2005,
#   'Epioblasma torulosa gubernaculum',
#   'Epioblasma torulosa gubernaculum',
#   '',
#   'Epioblasma torulosa',
#   'http://services.itis.gov/?q=tsn:80341',
#   'http://services.itis.gov/?q=tsn:80337'],
#  [2005,
#   'Epioblasma torulosa torulosa',
#   'Epioblasma torulosa torulosa',
#   '',
#   'Epioblasma torulosa',
#   'http://services.itis.gov/?q=tsn:80339',
#   'http://services.itis.gov/?q=tsn:80337'],
#  [2005,
#   'Tetragoneuria canis',
#   'Tetragoneuria canis',
#   '',
#   'Epitheca canis',
#   'http://services.itis.gov/?q=tsn:102002',
#   'http://services.itis.gov/?q=tsn:102036'],
#  [2005,
#   'Tetragoneuria costalis',
#   'Tetragoneuria costalis',
#   '',
#   'Epitheca costalis',
#   'http://services.itis.gov/?q=tsn:101995',
#   'http://services.itis.gov/?q=tsn:593049'],
#  [2005,
#   'Tetragoneuria petechialis',
#   'Tetragoneuria petechialis',
#   '',
#   'Epitheca petechialis',
#   'http://services.itis.gov/?q=tsn:102001',
#   'http://services.itis.gov/?q=tsn:593050'],
#  [2005,
#   'Tetragoneuria semiaquea',
#   'Tetragoneuria semiaquea',
#   '',
#   'Epitheca semiaquea',
#   'http://services.itis.gov/?q=tsn:101997',
#   'http://services.itis.gov/?q=tsn:593051'],
#  [2005,
#   'Tetragoneuria spinosa',
#   'Tetragoneuria spinosa',
#   '',
#   'Epitheca spinosa',
#   'http://services.itis.gov/?q=tsn:101999',
#   'http://services.itis.gov/?q=tsn:593052'],
#  [2005,
#   'Epitrix sp. EGR 1',
#   'Epitrix',
#   '',
#   'Epitrix',
#   'http://services.itis.gov/?q=tsn:187773',
#   'http://services.itis.gov/?q=tsn:187773'],
#  [2005,
#   'Eragrostis glomerata',
#   'Eragrostis glomerata',
#   '',
#   'Eragrostis japonica',
#   'http://services.itis.gov/?q=tsn:40743',
#   'http://services.itis.gov/?q=tsn:565170'],
#  [2005,
#   'Trichodrilus allegheniensis',
#   'Trichodrilus allegheniensis',
#   '',
#   'Eremidrilus allegheniensis',
#   'http://services.itis.gov/?q=tsn:68461',
#   'http://services.itis.gov/?q=tsn:974737'],
#  [2005,
#   'Eremobina jocasta',
#   'Eremobina jocasta',
#   '',
#   'Eremobina leucoscelis',
#   'http://services.itis.gov/?q=tsn:940878',
#   'http://services.itis.gov/?q=tsn:938554'],
#  [2005,
#   'Erethizon dorsatum',
#   'Erethizon dorsatum',
#   '',
#   'Erethizon dorsatus',
#   'http://services.itis.gov/?q=tsn:180393',
#   'http://services.itis.gov/?q=tsn:825295'],
#  [2005,
#   'Erethizon dorsatum',
#   'Erethizon dorsatum',
#   '',
#   'Erethizon dorsatus',
#   'http://services.itis.gov/?q=tsn:180393',
#   'http://services.itis.gov/?q=tsn:825295'],
#  [2005,
#   'Erethizon dorsatum',
#   'Erethizon dorsatum',
#   '',
#   'Erethizon dorsatus',
#   'http://services.itis.gov/?q=tsn:180393',
#   'http://services.itis.gov/?q=tsn:825295'],
#  [2005,
#   'Erethizon dorsatum',
#   'Erethizon dorsatum',
#   '',
#   'Erethizon dorsatus',
#   'http://services.itis.gov/?q=tsn:180393',
#   'http://services.itis.gov/?q=tsn:825295'],
#  [2005,
#   'Erethizon dorsatum',
#   'Erethizon dorsatum',
#   '',
#   'Erethizon dorsatus',
#   'http://services.itis.gov/?q=tsn:180393',
#   'http://services.itis.gov/?q=tsn:825295'],
#  [2005,
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricata',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173836',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Eretmochelys imbricata imbricat',
#   'Eretmochelys imbricata imbricat',
#   '',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173837',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Eretmochelys imbricata imbricata',
#   'Eretmochelys imbricata imbricata',
#   '',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173837',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Eretmochelys imbricata imbricata',
#   'Eretmochelys imbricata imbricata',
#   '',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173837',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricata',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173836',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricate',
#   'Eretmochelys imbricata',
#   'Eretmochelys imbricata',
#   'http://services.itis.gov/?q=tsn:173836',
#   'http://services.itis.gov/?q=tsn:173836'],
#  [2005,
#   'Erigeron ochroleucus var. scribneri',
#   'Erigeron ochroleucus var. scribneri',
#   '',
#   'Erigeron ochroleucus var. ochroleucus',
#   'http://services.itis.gov/?q=tsn:527951',
#   'http://services.itis.gov/?q=tsn:527950'],
#  [2005,
#   'Erigrathus barbatus',
#   'Erigrathus barbatus',
#   'Erignathus barbatus',
#   'Erignathus barbatus',
#   'http://services.itis.gov/?q=tsn:180655',
#   'http://services.itis.gov/?q=tsn:180655'],
#  [2005,
#   'Cyprinella monacha',
#   'Cyprinella monacha',
#   '',
#   'Erimonax monachus',
#   'http://services.itis.gov/?q=tsn:163795',
#   'http://services.itis.gov/?q=tsn:689041'],
#  [2005,
#   'Erimonax monacha',
#   'Erimonax monacha',
#   'Erimonax monachus',
#   'Erimonax monachus',
#   'http://services.itis.gov/?q=tsn:689041',
#   'http://services.itis.gov/?q=tsn:689041'],
#  [2005,
#   'Cyprinella monacha',
#   'Cyprinella monacha',
#   '',
#   'Erimonax monachus',
#   'http://services.itis.gov/?q=tsn:163795',
#   'http://services.itis.gov/?q=tsn:689041'],
#  [2005,
#   'Erimytax x-punctatus',
#   'Erimytax x-punctatus',
#   'Erimystax x-punctatus',
#   'Erimystax x-punctatus',
#   'http://services.itis.gov/?q=tsn:163824',
#   'http://services.itis.gov/?q=tsn:163824'],
#  [2005,
#   'Erimystax x-punctata',
#   'Erimystax x-punctata',
#   'Erimystax x-punctatus',
#   'Erimystax x-punctatus',
#   'http://services.itis.gov/?q=tsn:163824',
#   'http://services.itis.gov/?q=tsn:163824'],
#  [2005,
#   'Eschrichtius robustus, pop. 4',
#   'Eschrichtius robustus',
#   '',
#   'Eschrichtius robustus',
#   'http://services.itis.gov/?q=tsn:180521',
#   'http://services.itis.gov/?q=tsn:180521'],
#  [2005,
#   'Coryphantha missouriensis',
#   'Coryphantha missouriensis',
#   '',
#   'Escobaria missouriensis ssp. missouriensis',
#   'http://services.itis.gov/?q=tsn:19830',
#   'http://services.itis.gov/?q=tsn:912701'],
#  ...]
