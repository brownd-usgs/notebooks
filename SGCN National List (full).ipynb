# %% [markdown]
# # SGCN National List
#
# The full list of SGCN species across 2005 and 2015 represents a relatively complex query that needs to sum up the total states reporting each species. This notebook runs a query against the index in our data infrastructure and displays the full list of the species names that have been successfully matched against a taxonomic authority. This is currently how we are defining that a species name should be on the "National List."
#
# The query in this notebook is what will be executed for the new [national list page](https://www1.usgs.gov/csas/swap/national_list.html) in the online SWAP app.

# %%
import requests
from ipywidgets import interactive
import ipywidgets as widgets
from IPython.display import display

# %%
#Class to render tables
class ListTable(list):
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
sgcnNationalListURL = "https://gc2.mapcentia.com/api/v1/elasticsearch/search/bcb/public/sgcn_nationallist?size=10000"
sgcnNationalList = requests.get(sgcnNationalListURL).json()

tableNationalList = ListTable()
tableNationalList.append(['Scientific Name', 'Common Name', '2005', '2015', 'Taxonomic Group', 'Taxonomic Authority ID/Link'])

for hit in sgcnNationalList['hits']['hits']:
    tableNationalList.append([hit['_source']['properties']['scientificname'], hit['_source']['properties']['commonname'], hit['_source']['properties']['sgcn2005'], hit['_source']['properties']['sgcn2015'], hit['_source']['properties']['taxonomicgroup'], hit['_source']['properties']['taxonomicauthorityid']])

# %% [markdown]
# This query returns results from the Elasticsearch index for the sgcn_nationallist view. It only calls the first 100 results, so that will need to be paginated for the SWAP online app.
#
# ### Property Notes
#
# * Scientific Name - accepted scientific name from the taxonomic authority
# * Common Name - common name provided on the state lists (single option shown here when there are cases when different states use different common names)
# * 2005 - number of states reporting the species in 2005
# * 2015 - number of states reporting the species in 2015 (not all states have yet submitted 2015 lists)
# * Taxonomic Group - group provided by the state lists
# * Taxonomic Authority ID - Included as a reference. IDs to ITIS or WoRMS return a machine-readable response and are not content negotiable, so if we want to include them in the UI, we would need to translate the ID into something for humans.

# %%
print ("Total species on National List: "+str(sgcnNationalList['hits']["total"]))

display(tableNationalList)
# Out:
# Total species on National List: 14158
# [['Scientific Name',
#   'Common Name',
#   '2005',
#   '2015',
#   'Taxonomic Group',
#   'Taxonomic Authority ID/Link'],
#  ['Abagrotis brunneipennis',
#   'Yankee Dart',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:771341'],
#  ['Abagrotis nefascia',
#   'Coastal Heathland Cutworm',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:771359'],
#  ['Abagrotis orbis',
#   'A noctuid moth',
#   2,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:771360'],
#  ['Ablautus schlingeri',
#   'Oso Flaco Robber Fly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:132569'],
#  ['Abutilon sandwicense',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:21681'],
#  ['Acalypha ostryifolia',
#   'Rough-pod Copperleaf',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:28189'],
#  ['Acanthuridae',
#   'Surgeonfish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:172250'],
#  ['Acanthurus coeruleus',
#   'Blue Tang',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:172254'],
#  ['Acartia tonsa',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:86088'],
#  ['Acella haldemani',
#   'Spindle Lymnaea',
#   5,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:76531'],
#  ['Acetropis americana',
#   'American grass bug',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:105544'],
#  ['Achyranthes mutica',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:20758'],
#  ['Acipenser oxyrinchus',
#   'Atlantic Sturgeon',
#   14,
#   8,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:553269'],
#  ['Acleisanthes parvifolia',
#   'Littleleaf moonpod',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:895406'],
#  ['Acrididae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102195'],
#  ['Acrocephalus familiaris kingi',
#   'Nihoa millerbird',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:202291'],
#  ['Acroloxus coloradensis',
#   'Rocky Mountain capshell',
#   2,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:76475'],
#  ['Acroneuria kosztarabi',
#   "Kosztarab's common stonefly",
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:609899'],
#  ['Acroneuria petersi',
#   'A Stonefly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102928'],
#  ['Acronicta exilis',
#   'exiled dagger moth',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:937605'],
#  ['Acronicta increta',
#   'a dagger moth',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:937616'],
#  ['Acronicta rubricoma',
#   'a dagger moth',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:937637'],
#  ['Acropora cytherea',
#   'table coral',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:52907'],
#  ['Acropora palmata',
#   'Elkhorn Coral',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:52861'],
#  ['Acropora prolifera',
#   'Fused Staghorn Coral',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:52863'],
#  ['Acroporidae',
#   'NA',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:52859'],
#  ['Actinemys marmorata',
#   'Western Pond Turtle',
#   6,
#   3,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:668668'],
#  ['Adelocosa anops',
#   'Kauai cave wolf spider',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:849993'],
#  ['Adenophorus periens',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17844'],
#  ['Adiantum aleuticum',
#   'Aleutian Maidenhair-fern',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:181788'],
#  ['Aegialia concinna',
#   'Ciervo Aegialian Scarab Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:926712'],
#  ['Aeropedellus clavatus',
#   'Club-horned Grasshopper',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657840'],
#  ['Aesculus glabra var. arguta',
#   'Ohio Buckeye',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:28720'],
#  ['Aeshna interrupta',
#   'Variable Darner',
#   1,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:185979'],
#  ['Aethia cristatella',
#   'Crested Auklet',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:177019'],
#  ['Aethia pusilla',
#   'Least Auklet',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:177020'],
#  ['Aethra edentata',
#   'flat elbow crab',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:660519'],
#  ['Agabus aeruginosus',
#   'A Predaceous Diving Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:112009'],
#  ['Agabus canadensis',
#   'A Predaceous Diving Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:112001'],
#  ['Agabus confinis',
#   'A Predaceous Diving Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:111997'],
#  ['Agabus leptapsis',
#   'A Predaceous Diving Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:112017'],
#  ['Agalinis calycina',
#   'Leoncita false foxglove',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33010'],
#  ['Agalinis densiflora',
#   'Osage Plains false foxglove',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:182271'],
#  ['Agalinis heterophylla',
#   'Prairie false foxglove',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33027'],
#  ['Agalinis tenuifolia',
#   'Narrow-leaf False Foxglove',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33036'],
#  ['Agallissus lepturoides',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:702422'],
#  ['Agarodes distinctus',
#   'A Caddisfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:116984'],
#  ['Agastache foeniculum',
#   'Lavender Giant-hyssop',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:32440'],
#  ['Agastache nepetoides',
#   'Yellow Giant Hyssop',
#   2,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:32443'],
#  ['Agave X glomeruliflora',
#   'Chisos agave',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:810235'],
#  ['Agelenopsis emertoni',
#   "Emerton's Grass Spider",
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:873664'],
#  ['Agkistrodon contortrix contortrix',
#   'Southern Copperhead',
#   0,
#   1,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:174298'],
#  ['Agkistrodon contortrix pictigaster',
#   'Trans-Pecos copperhead',
#   1,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:209500'],
#  ['Aglaophamus verrilli',
#   'Dwarf sandworm',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:66052'],
#  ['Agonum decorum',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:110277'],
#  ['Agonum superioris',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:110356'],
#  ['Agrimonia incisa',
#   'Incised Groovebur',
#   0,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25096'],
#  ['Agrotis obliqua',
#   'A noctuid moth',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:188679'],
#  ['Agrypnia vestita',
#   'Unbanded Agrypnia Caddisfly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:115884'],
#  ['Aimophila ruficeps',
#   'Rufous-crowned Sparrow',
#   2,
#   2,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:179377'],
#  ['Aiptasia eruptaurantia',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:52771'],
#  ['Aix sponsa',
#   'Wood Duck',
#   5,
#   3,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175122'],
#  ['Alasmidonta arcula',
#   'Altamaha Arcmussel',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:79921'],
#  ['Alauda arvensis',
#   'Sky Lark',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:178398'],
#  ['Albula vulpes',
#   'Bonefish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161121'],
#  ['Alectryon macrococcus var. macrococcus',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:184733'],
#  ['Aliciella pinnatifida',
#   'Sticky Gilia',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:845222'],
#  ['Allium canadense',
#   'wild garlic',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:42635'],
#  ['Allium canadense var. fraseri',
#   "Fraser's Wild Onion",
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:526867'],
#  ['Allocapnia cunninghami',
#   'Karst Snowfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102668'],
#  ['Allocapnia harperi',
#   'Stonyfork Snowfly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102671'],
#  ['Allocapnia jeanae',
#   'Winter Stonefly',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102674'],
#  ['Allocapnia malverna',
#   'Winter Stonefly',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102675'],
#  ['Allogona profunda',
#   'Broad-banded Forestsnail',
#   1,
#   2,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77464'],
#  ['Allolepis texana',
#   'Texas false saltgrass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41380'],
#  ['Allomyia scotti',
#   "Scott's apatanian caddisfly",
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:604639'],
#  ['Alloperla biserrata',
#   'Dusky Sallfly',
#   2,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:103219'],
#  ['Alloperla leonarda',
#   'Truncate Sallfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:103207'],
#  ['Allopodops mississippiensis',
#   'Mississippi turtle bug',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109000'],
#  ['Alosa chrysochloris',
#   'Skipjack herring',
#   3,
#   4,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161707'],
#  ['Alosa pseudoharengus',
#   'Alewife',
#   7,
#   5,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161706'],
#  ['Alpheus normanni',
#   'Bigclaw snapping shrimp',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:96606'],
#  ['Alphitonia ponderosa',
#   'kauila',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:28452'],
#  ['Aluterus heudelotii',
#   'Dotterel Filefish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:173132'],
#  ['Alyxia stellata',
#   'maile',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:893855'],
#  ['Amara laevipennis',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:110894'],
#  ['Amaranthus brownii',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:181924'],
#  ['Amaranthus tuberculatus',
#   'Water Hemp',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:20750'],
#  ['Amathia distans',
#   "Delicate sheep's-wool bryozoan",
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:155556'],
#  ['Amblycheila picolominii',
#   'Tiger Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:697665'],
#  ['Amblyderus werneri',
#   'Great Sand Dunes anthicid beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:685510'],
#  ['Amblyscirtes cassus',
#   'Cassus Roadside-Skipper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:706570'],
#  ['Ambystoma cingulatum',
#   'Flatwoods Salamander',
#   4,
#   2,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173596'],
#  ['Ambystoma texanum',
#   'Smallmouth Salamander',
#   5,
#   5,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173605'],
#  ['Ameiurus nebulosus',
#   'Brown bullhead',
#   5,
#   3,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:164043'],
#  ['Ameiurus serracanthus',
#   'Spotted Bullhead',
#   2,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:164047'],
#  ['Ameletus lineatus',
#   'A Mayfly',
#   2,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101009'],
#  ['Americamysis almyra',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:682616'],
#  ['Americhelidium americanum',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:657118'],
#  ['Amerigoniscus malheurensis',
#   'Malheur Isopod',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:594158'],
#  ['Amerigoniscus nicholasi',
#   '(a cave obligate isopod)',
#   2,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:594159'],
#  ['Ametropus ammophilus',
#   'A Mayfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101077'],
#  ['Amia calva',
#   'Bowfin',
#   3,
#   3,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161104'],
#  ['Ammannia auriculata',
#   'Ear-leaf Toothcup',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:27093'],
#  ['Ammocrypta clara',
#   'Western sand darter',
#   14,
#   9,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:168515'],
#  ['Ammodramus savannarum ammolegus',
#   'Arizona Grasshopper Sparrow',
#   1,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:179337'],
#  ['Ammodramus savannarum perpallidus',
#   'Grasshopper Sparrow',
#   1,
#   2,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:179336'],
#  ['Ammodytes hexapterus',
#   'Pacific sand lance',
#   2,
#   2,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:171672'],
#  ['Ammodytoides pylei',
#   "Pyle's sand lance",
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:630417'],
#  ['Ammopelmatus kelsoensis',
#   'Kelso Jerusalem Cricket',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657868'],
#  ['Ammospermophilus interpres',
#   'Texas antelope squirrel',
#   1,
#   1,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:180180'],
#  ['Amnicola granum',
#   'squat duskysnail',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70772'],
#  ['Amnicola limosus',
#   'Mud Amnicola',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70748'],
#  ['Amnicola rhombostoma',
#   'Squaremouth Amnicola',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70776'],
#  ['Amnicola stygius',
#   'Stygian amnicola',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70777'],
#  ['Amolita roseola',
#   'A noctuid moth',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:937706'],
#  ['Amorpha juglandis',
#   'walnut sphinx',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:936021'],
#  ['Amphiachyris dracunculoides',
#   'Prairie Broomweed',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:36525'],
#  ['Amphiporeia virginiana',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:93988'],
#  ['Amphiporus cruentatus',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:57538'],
#  ['Amphiporus ochraceus',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:57535'],
#  ['Amphisbaena fenestrata',
#   'Amphisbaena',
#   1,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:209631'],
#  ['Amphistichus rhodoterus',
#   'Redtail Surfperch',
#   0,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:169757'],
#  ['Ampithoe valida',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:93424'],
#  ['Analetris eximia',
#   'A Mayfly',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:100993'],
#  ['Anarrhichthys ocellatus',
#   'Wolf-eel',
#   0,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:171345'],
#  ['Anas americana',
#   'American Wigeon',
#   4,
#   2,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175094'],
#  ['Anas fulvigula',
#   'Mottled Duck',
#   4,
#   4,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175070'],
#  ['Anas laysanensis',
#   'Laysan duck',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175119'],
#  ['Anax longipes',
#   'Comet Darner',
#   9,
#   7,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101599'],
#  ['Anaxyrus americanus americanus',
#   'American Toad',
#   3,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:776684'],
#  ['Anaxyrus baxteri',
#   'Wyoming Toad',
#   1,
#   1,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:773512'],
#  ['Anaxyrus boreas',
#   'Western toad (Western WA only)',
#   5,
#   5,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:773513'],
#  ['Anaxyrus boreas boreas',
#   'Boreal toad (Southern Rocky Mountain Population)',
#   3,
#   2,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:776686'],
#  ['Anaxyrus hemiophrys',
#   'Canadian Toad',
#   1,
#   1,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:773521'],
#  ['Anaxyrus houstonensis',
#   'Houston toad',
#   1,
#   1,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:773522'],
#  ['Anchoa lyolepis',
#   'Dusky Anchovy',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161842'],
#  ['Andrena blennospermatis',
#   'No common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:654188'],
#  ['Andrena micheneri',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:654385'],
#  ['Andrena vogleri',
#   'Andrenid Bee',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:753085'],
#  ['Anepeorus rusticus',
#   'A Sand-dwelling Mayfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:100664'],
#  ['Anguinella palmata',
#   'Muddy-tuft bryozoan',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:155542'],
#  ['Anguispira jessica',
#   'Mountain disc',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77387'],
#  ['Anisodoris prea',
#   'No common name',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78185'],
#  ['Anodonta kennerlyi',
#   'Western floater',
#   2,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:79942'],
#  ['Anodonta oregonensis',
#   'Oregon floater',
#   2,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:79949'],
#  ['Anodontoides ferussacianus',
#   'Cylindrical Papershell',
#   10,
#   9,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80148'],
#  ['Anodontoides radiatus',
#   'Rayed Creekshell',
#   3,
#   2,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80149'],
#  ['Anser albifrons gambeli',
#   'Tule greater white-fronted goose',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:714773'],
#  ['Antennaria dimorpha',
#   'Low Pussytoes',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:36727'],
#  ['Anthanassa texana seminole',
#   'Seminole Crescent',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:779425'],
#  ['Anthemiphyllia pacifica',
#   'no common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:571828'],
#  ['Anthicus sacramento',
#   'Sacramento Anthicid Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:685434'],
#  ['Anthocharis midea',
#   'Falcate Orangetip',
#   2,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777759'],
#  ['Anthocharis sara alaskensis',
#   'Alaskan orange tip',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:778525'],
#  ['Anthoxanthum monticola',
#   'alpine sweet-grass',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:508922'],
#  ['Anticlea elegans var. elegans',
#   'Mountain White-camas',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:810373'],
#  ['Antilocapra americana americana',
#   'America Pronghorn',
#   1,
#   1,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:202417'],
#  ['Antipathes barbadensis',
#   'Bottle Bruch Black Coral',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:51953'],
#  ['Antipathes subpinnata',
#   'no common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:204150'],
#  ['Antithamnion erucacladellum',
#   'no common name',
#   1,
#   0,
#   'Algae',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/374606'],
#  ['Antrolana lira',
#   'Madison Cave isopod',
#   2,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92263'],
#  ['Antrozous pallidus',
#   'Pallid Bat',
#   6,
#   4,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:180006'],
#  ['Apalone ferox',
#   'Florida Softshell Turtle',
#   1,
#   1,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:208675'],
#  ['Apalone spinifera spinifera',
#   'Western Spiny Softshell',
#   3,
#   4,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:208693'],
#  ['Aphaenogaster punctaticeps',
#   'Ant',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:578446'],
#  ['Aphaostracon pycnum',
#   'Dense Hydrobe Snail',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70629'],
#  ['Aphelochaeta marioni',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:573737'],
#  ['Aphotaenius carolinus',
#   'Carolina Forest Scarab',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:927250'],
#  ['Aphrissa statira',
#   'Statira',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777755'],
#  ['Aphylla williamsoni',
#   'Two-striped forceptail',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101716'],
#  ['Apidae', 'NA', 0, 1, 'Insects', 'http://services.itis.gov/?q=tsn:154394'],
#  ['Aplectrum hyemale',
#   'Putty-root',
#   1,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:43489'],
#  ['Aplodontia rufa nigra',
#   'Point Arena Mountain Beaver',
#   1,
#   0,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:202351'],
#  ['Apocheiridium reddelli',
#   'A cave obligate pseudoscorpion',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:749050'],
#  ['Apochthonius coecus',
#   'Cave pseudoscorpion',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:198419'],
#  ['Apochthonius titanicus',
#   'Cave Obligate Pseudoscorpion',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:198439'],
#  ['Apochthonius typhlus',
#   'Stone county cave pseudoscorpion',
#   1,
#   1,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:198440'],
#  ['Apocorophium acutum',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:656748'],
#  ['Apocorophium simile',
#   'No common name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:656751'],
#  ['Apodemia mormo langei',
#   "Lange's Metalmark",
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:201270'],
#  ['Apogon aurolineatus',
#   'Bridle Cardinalfish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:168201'],
#  ['Apogon binotatus',
#   'Barred Cardinalfish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:168202'],
#  ['Arabidopsis lyrata ssp. lyrata',
#   'lyre-leaved rock-cress',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:823323'],
#  ['Arabis georgiana',
#   'Georgia Rockcress',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:22694'],
#  ['Arachosia cubana',
#   'A Ghost Spider',
#   0,
#   1,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:874410'],
#  ['Araneidae', 'NA', 0, 1, 'Insects', 'http://services.itis.gov/?q=tsn:82737'],
#  ['Araneus groenlandicola',
#   'an orb-web spider',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:851459'],
#  ['Aratus pisonii',
#   'Mangrove Crab',
#   2,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:99062'],
#  ['Arborimus longicaudus',
#   'Red Tree Vole',
#   1,
#   1,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:180353'],
#  ['Arceuthobium pusillum',
#   'Dwarf Mistletoe',
#   1,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:27895'],
#  ['Archidium alternifolium',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:15802'],
#  ['Arctiinae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:693997'],
#  ['Arctosa rubicunda',
#   'Reddish Arctosa',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:852007'],
#  ['Arctosa sanctaerosae',
#   'Santa Rosa Wolf Spider',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:852009'],
#  ['Arenaeus cribrarius',
#   'Speckled swimming crab',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:98691'],
#  ['Argiacris keithi',
#   'A Grasshopper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657905'],
#  ['Argiacris militaris',
#   'A Grasshopper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657906'],
#  ['Argia plana',
#   'Springwater Dancer',
#   1,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102151'],
#  ['Argia sedula',
#   'Blue-ringed Dancer',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102147'],
#  ['Argia tibialis',
#   'Blue-tipped dancer',
#   2,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102148'],
#  ['Argythamnia argyraea',
#   'Silvery wild-mercury',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:184700'],
#  ['Aricidea wassi',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:66673'],
#  ['Arida mattturneri',
#   "Matt Turner's aster",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:780192'],
#  ['Ariopsis felis',
#   'Hardhead Catfish',
#   1,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:680665'],
#  ['Aristida purpurascens',
#   'Purple Needlegrass',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41428'],
#  ['Aristida purpurascens var. purpurascens',
#   'Arrowfeather Three-awn',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:185309'],
#  ['Aristida ramosissima',
#   'Slender Three-awn',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41430'],
#  ['Aristida tuberculosa',
#   'Seabeach Needlegrass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41436'],
#  ['Armandia maculata',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:67347'],
#  ['Armases benedicti',
#   "Benedict's Wharf Crab",
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:660770'],
#  ['Armiger crista',
#   'Star Gyro',
#   3,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:76619'],
#  ['Armina tigrina',
#   'Tiger armina',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78569'],
#  ['Artemisiospiza belli clementeae',
#   'San Clemente Sage Sparrow',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:998053'],
#  ['Arthropoda',
#   'Crustaceans, Spiders, Insects',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:82696'],
#  ['Asaphomyia floridensis',
#   'Florida Asaphomyian Tabanid Fly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:130956'],
#  ['Asclepias verticillata',
#   'Whorled Milkweed',
#   0,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:30320'],
#  ['Aseraggodes therese',
#   "Therese's sole",
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:616264'],
#  ['Ashmunella carlsbadensis',
#   'Guadalupe woodlandsnail',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77475'],
#  ['Ashmunella macromphala',
#   "Cook's Peak Woodlandsnail",
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77486'],
#  ['Ashmunella mendax',
#   'Iron Creek Woodlandsnail',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77488'],
#  ['Ashmunella mudgei',
#   'Sawtooth Mountain woodlandsnail',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77490'],
#  ['Ashmunella pilsbryana',
#   'NA',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77493'],
#  ['Ashmunella proxima',
#   'NA',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77494'],
#  ['Asio flammeus flammeus',
#   'Short-eared Owl',
#   0,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:177936'],
#  ['Asio flammeus sandwichensis',
#   'Hawaiian short-eared owl, pueo',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:687200'],
#  ['Asplenium monanthes',
#   'Single-sorus Spleenwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17350'],
#  ['Asplenium pinnatifidum',
#   'Lobed Spleenwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17354'],
#  ['Asplenium X heteroresiliens',
#   "Wagner's Spleenwort",
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17347'],
#  ['Asterinidae',
#   'NA',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:157120'],
#  ['Asteropseidae',
#   'NA',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:655997'],
#  ['Astragalus bodinii',
#   "Bodin's Milk-vetch",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25439'],
#  ['Astragalus cronquistii',
#   'Cronquist milkvetch',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25482'],
#  ['Astragalus debequaeus',
#   'DeBeque milkvetch',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:192812'],
#  ['Astragalus hyalinus',
#   'Summer Orophaca',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25541'],
#  ['Astragalus lotiflorus',
#   'Low Milk Vetch',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25568'],
#  ['Astragalus piscator',
#   'Fisher Towers milkvetch',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:192819'],
#  ['Astragalus robbinsii var. minor',
#   "Blake's Milk-vetch",
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:192749'],
#  ['Astragalus tyghensis',
#   'Tygh Valley Milkvetch',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:25713'],
#  ['Astranthium ciliatum',
#   'Western Daisy',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:780222'],
#  ['Astrapogon puncticulatus',
#   'Blackfin Cardinalfish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:168286'],
#  ['Astrophyton muricatum',
#   'Basket Star',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:157366'],
#  ['Ataenius brevicollis',
#   'An Ataenius Beetle',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:927265'],
#  ['Atheta annexa',
#   'A rove beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:724960'],
#  ['Atlanticus davisi',
#   "Davis's shield-bearer",
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657931'],
#  ['Atractelmis wawona',
#   'Wawona Riffle Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:114252'],
#  ['Atrichum cylindricum',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:547548'],
#  ['Atrytonopsis',
#   'Crystal Skipper',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:706398'],
#  ['Atrytonopsis deva',
#   'Deva Skipper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:706594'],
#  ['Atrytonopsis lunus',
#   'Moon-marked Skipper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:706598'],
#  ['Attheyella illinoisensis',
#   'A Copepod',
#   2,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:88234'],
#  ['Attheyella obatogamensis',
#   'A Copepod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:88224'],
#  ['Atyidae',
#   'Atyid shrimp',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:97243'],
#  ['Aulacomnium androgynum',
#   'A Moss',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:547553'],
#  ['Aureolaria flava',
#   'Smooth False-foxglove',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33484'],
#  ['Aureolaria patula',
#   'Spreading Yellow Foxglove',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33487'],
#  ['Awaous banana',
#   'River goby',
#   3,
#   2,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:553409'],
#  ['Awaous guamensis',
#   'oopu nakea',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:553326'],
#  ['Aythya affinis',
#   'Lesser Scaup',
#   21,
#   11,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175134'],
#  ['Aythya americana',
#   'Redhead',
#   12,
#   5,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175125'],
#  ['Bacopa innominata',
#   'Coastal-plain Water-hyssop',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:33042'],
#  ['Bactrurus brachycaudus',
#   'Short-tailed Groundwater Amphipod',
#   2,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:656767'],
#  ['Baeolophus atricristatus',
#   'Black-crested titmouse',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:558842'],
#  ['Baetisca carolina',
#   'A Mayfly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101499'],
#  ['Baetisca escambiensis',
#   'A Mayfly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101502'],
#  ['Bairdiella chrysoura',
#   'Silver Perch',
#   1,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:169259'],
#  ['Balaenoptera bonaerensis',
#   'Minke whale',
#   1,
#   0,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:612592'],
#  ['Balaenoptera borealis',
#   'Sei whale',
#   12,
#   5,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:180526'],
#  ['Balduina atropurpurea',
#   'Purple Balduina',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:36804'],
#  ['Barbaetis benfieldi',
#   'Benfield���������s Bearded Small Minnow Mayfly',
#   1,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:609542'],
#  ['Barbilophozia kunzeana',
#   'A Liverwort',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:14722'],
#  ['Barentsia laxa',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:156743'],
#  ['Barnea truncata',
#   'Atlantic mud piddock',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:81798'],
#  ['Barronopsis jeffersi',
#   'A funnel-web spider',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:874841'],
#  ['Bartonia texana',
#   'Texas screwstem',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:30023'],
#  ['Bartramia longicauda',
#   'Upland Sandpiper',
#   34,
#   21,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176610'],
#  ['Basilia boardmani',
#   'Southeastern myotis bat fly',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:152712'],
#  ['Bathypathes conferta',
#   'no common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/589657'],
#  ['Batrachoseps campi',
#   'Inyo Mountains Slender Salamander',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173707'],
#  ['Batrachoseps relictus',
#   'Relictual Slender Salamander',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:208344'],
#  ['Batrachoseps stebbinsi',
#   'Tehachapi Slender Salamander',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173711'],
#  ['Batriasymmodes quisnamus',
#   '(a cave obligate beetle)',
#   2,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:691457'],
#  ['Batrisodes lineaticollis',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:691594'],
#  ['Batrisodes uncicornis',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:691260'],
#  ['Bazzania trilobata',
#   'A Liverwort',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:14366'],
#  ['Behningiidae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101522'],
#  ['Belocephalus sleighti',
#   'Keys Short-winged Conehead Katydid',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657946'],
#  ['Bembidion affine',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109955'],
#  ['Bembidion carinula',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109795'],
#  ['Bembidion grapii',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:932111'],
#  ['Bembidion muscicola',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109971'],
#  ['Bembidion pseudocautum',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109982'],
#  ['Bembidion robusticolle',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109799'],
#  ['Bembidion simplex',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109833'],
#  ['Berghia benteva',
#   'No common name',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78733'],
#  ['Berosus pantherinus',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:112823'],
#  ['Berula erecta',
#   'Cut-leaved water-parsnip',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:29596'],
#  ['Betula minor',
#   'Dwarf Birch',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:183534'],
#  ['Bhawania heteroseta',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:65159'],
#  ['Bibloplectus chickasaw',
#   'A Staphylinid Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:691284'],
#  ['Bidens hyperborea',
#   'Estuary Beggar-ticks',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:35725'],
#  ['Birgella subglobosus',
#   'Globe Slitsnail',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:70667'],
#  ['Blarina hylophaga plumbea',
#   'Elliot���������s short-tailed shrew',
#   1,
#   1,
#   'Mammals',
#   'http://services.itis.gov/?q=tsn:709900'],
#  ['Blepharicera',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:121255'],
#  ['Blepharidachne bigelovii',
#   "Bigelow's desert grass",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41472'],
#  ['Blethisa julii',
#   'A Ground Beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:109559'],
#  ['Bobea elatior',
#   'ahakea',
#   2,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:35154'],
#  ['Boccardiella hamata',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:67011'],
#  ['Boechera glareosa',
#   "Dorn's rockcress",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:823255'],
#  ['Boechera grahamii',
#   "Graham's Rock Cress",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:822987'],
#  ['Boechera laevigata',
#   'Smooth Rock-cress',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:823180'],
#  ['Bolbometopon muricatum',
#   'Green humphead parrotfish',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:170884'],
#  ['Bolboschoenus maritimus',
#   'salt-marsh bulrush',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:508145'],
#  ['Boloria alberta',
#   'Alberta Fritillary',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777987'],
#  ['Boloria bellona toddi',
#   'Meadow fritillary',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:779080'],
#  ['Boloria selene atrocostalis',
#   'Silver-bordered fritillary',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:779077'],
#  ['Bombus borealis',
#   'Northern amber bumble bee',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714789'],
#  ['Bombus fervidus',
#   'Yellow bumble bee',
#   0,
#   9,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714802'],
#  ['Bombus fraternus',
#   'Southern plains bumble bee',
#   1,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714805'],
#  ['Bombus rufocinctus',
#   'Red-belted Bumble Bee',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714833'],
#  ['Bombus terricola',
#   'Yellowbanded Bumble Bee',
#   0,
#   11,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714843'],
#  ['Bombus variabilis',
#   'Variable cuckoo bumblebee',
#   0,
#   4,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:714847'],
#  ['Bombycilla garrulus',
#   'Bohemian Waxwing',
#   1,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:178529'],
#  ['Booneacris glacialis',
#   'Wingless Mountain Grasshopper',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:657950'],
#  ['Boonea impressa',
#   'Impressed odostome',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:75989'],
#  ['Boreotrophon clathratus',
#   'Clathrate Trophon',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:73331'],
#  ['Botrychium ascendens',
#   'Upswept Moonwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:501017'],
#  ['Botrychium lunaria',
#   'Common Moonwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17181'],
#  ['Botrychium simplex',
#   'Least Moonwort',
#   0,
#   3,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17190'],
#  ['Botrylloides diegensis',
#   'orange sheath tunicate',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/252278'],
#  ['Bouteloua gracilis',
#   'Blue Grama',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41493'],
#  ['Bouteloua kayi',
#   "Kay's grama",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41494'],
#  ['Boyeria grafiana',
#   'Ocellated darner',
#   4,
#   4,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101646'],
#  ['Brachinus fumans',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:111837'],
#  ['Brachoria falcifera',
#   'Big Cedar Creek millipede',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:570780'],
#  ['Brachoria separanda',
#   'A millipede',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:570795'],
#  ['Brachycentrus incanus',
#   'A Caddisfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:116919'],
#  ['Brackenridgia reddelli',
#   'A cave obligate isopod',
#   0,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:594681'],
#  ['Branchellion ravenelii',
#   '"A marine leech"',
#   0,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:69332'],
#  ['Branchinecta conservatio',
#   'Conservancy Fairy Shrimp',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:624021'],
#  ['Branchinecta lindahli',
#   'Versitle Fairy Shrimp',
#   2,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:83701'],
#  ['Branchinecta mackini',
#   'Akali Fairy Shrimp',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:83702'],
#  ['Branchinecta packardi',
#   'Rock Pool Fairy Shrimp',
#   2,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:83703'],
#  ['Brania clavata',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:65761'],
#  ['Branta sandvicensis',
#   'Hawaiian goose, nene',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175016'],
#  ['Brazoria truncata var. pulcherrima',
#   'Centerville Brazos-mint',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:566206'],
#  ['Brephidium exilis',
#   'Western Pygmy-Blue',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777886'],
#  ['Brevoortia tyrannus',
#   'Atlantic menhaden',
#   4,
#   2,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161732'],
#  ['Brickellia cordifolia',
#   'Heartleaf Brickellia',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:36870'],
#  ['Brickellia eupatorioides var. gracillima',
#   'Narrowleaf brickellbush',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:526979'],
#  ['Brighamia insignis',
#   'olulu',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:34622'],
#  ['Bromus porteri',
#   'Nodding Brome',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40486'],
#  ['Bromus ramosus',
#   'Coral ipomopsis',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:501076'],
#  ['Bryocamptus hutchinsoni',
#   'A Copepod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:667899'],
#  ['Bryum cyclophyllum',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:15969'],
#  ['Bryum miniatum',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:15977'],
#  ['Bryum subapiculatum',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:547642'],
#  ['Bubo virginianus',
#   'Great-horned Owl',
#   4,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:177884'],
#  ['Bugula neritina',
#   'Purple tuft bryozoan',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:156056'],
#  ['Bugula stolonifera',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:156064'],
#  ['Bulimulidae',
#   'NA',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77010'],
#  ['Busycon',
#   'whelk',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:74070'],
#  ['Buteo jamaicensis alascensis',
#   'Red-tailed Hawk',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175356'],
#  ['Buteo nitidus plagiatus',
#   'Northern Gray Hawk',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:824489'],
#  ['Cacostola lineata',
#   'A longhorned beetle',
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:702546'],
#  ['Caecidotea barri',
#   'Clifton Cave Isopod',
#   0,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92722'],
#  ['Caecidotea bicrenata',
#   'a cave obligate isopod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92724'],
#  ['Caecidotea henroti',
#   "Henrot's Cave isopod",
#   1,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92740'],
#  ['Caecidotea lesliei',
#   'isopod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92747'],
#  ['Caecidotea macropropoda',
#   'Bat Cave Isopod',
#   2,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:92748'],
#  ['Caecidotea richardsonae',
#   'Tennessee Valley cave isopod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92763'],
#  ['Caecidotea salemensis',
#   'Isopod',
#   2,
#   2,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:683364'],
#  ['Caecidotea sinuncus',
#   'An Isopod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92771'],
#  ['Caecidotea spatulata',
#   'a cave obligate isopod',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92773'],
#  ['Caecidotea stiladactyla',
#   'Isopod',
#   3,
#   2,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:92775'],
#  ['Caenis anceps',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101481'],
#  ['Caenis arwini',
#   'A mayfly',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:698074'],
#  ['Caenis diminuta',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101483'],
#  ['Caenis youngi',
#   'A Mayfly',
#   2,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:568627'],
#  ['Caesalpinia phyllanthoides',
#   'South Texas rushpea',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:26510'],
#  ['Calamagrostis canadensis',
#   "Langsdorf's Bluejoint",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40544'],
#  ['Calamovilfa brevipilis',
#   'Pine-barrens Reed-grass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41536'],
#  ['Calamovilfa longifolia var. longifolia',
#   'Long-leaved Reed Grass',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:527009'],
#  ['Calanus finmarchicus',
#   'A Copepod',
#   0,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:85272'],
#  ['Calcarea',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:46862'],
#  ['Calcarius pictus',
#   "Smith's Longspur",
#   7,
#   4,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:179529'],
#  ['Calicina arida',
#   'No common name',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:1013968'],
#  ['Calicina diminua',
#   'Marin Blind Harvestman',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:1013974'],
#  ['Calicina mesaensis',
#   'Table Mountain Harvestman',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:1013982'],
#  ['Calicina minor',
#   'Edgewood Blind Harvestman',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:1013983'],
#  ['Calidris acuminata',
#   'Sharp-tailed Sandpiper',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176652'],
#  ['Calidris alpina arcticola',
#   'Arctic Dunlin',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:824529'],
#  ['Calidris alpina hudsonia',
#   'Dunlin',
#   0,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:824531'],
#  ['Calidris alpina pacifica',
#   'Pacific Dunlin',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176663'],
#  ['Calidris ferruginea',
#   'Curlew sandpiper',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176660'],
#  ['Calidris mauri',
#   'Western Sandpiper',
#   10,
#   6,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176668'],
#  ['Calidris melanotos',
#   'Pectoral Sandpiper',
#   5,
#   4,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176653'],
#  ['Calidris subminuta',
#   'Long-toed Stint',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:176657'],
#  ['Calileptoneta briggsi',
#   "Briggs' Leptonetid Spider",
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:853114'],
#  ['Calileptoneta oasa',
#   'No common name',
#   1,
#   0,
#   'Arachnids',
#   'http://services.itis.gov/?q=tsn:853119'],
#  ['Callechelys lutea',
#   'yellowspotted snake eel, puhi',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:635433'],
#  ['Callibaetis skokianus',
#   'A Mayfly',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:100931'],
#  ['Calliergonella cuspidata',
#   'A Moss',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:16183'],
#  ['Calliergon richardsonii',
#   'no common name',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:16186'],
#  ['Callinectes sapidus',
#   'Blue crab',
#   7,
#   2,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:98696'],
#  ['Callipallene brevirostris',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:83670'],
#  ['Callitriche heterophylla',
#   'Large Water-starwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:32053'],
#  ['Callophrys augustinus',
#   'Brown Elfin',
#   3,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:188501'],
#  ['Callophrys irus',
#   'Frosted Elfin',
#   16,
#   7,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777851'],
#  ['Callophrys johnsoni',
# ...
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:98966'],
#  ['Distichopora violacea',
#   'Violet Lace Coral',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:50910'],
#  ['Distigmoptera impennata',
#   'A Leaf Beetle',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:720774'],
#  ['Dodecaceria concharum',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:67166'],
#  ['Dodonaea viscosa',
#   'aaliI',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:28675'],
#  ['Dolania americana',
#   'American Sand Burrowing Mayfly',
#   3,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101524'],
#  ['Doratonotus megalepis',
#   'Dwarf Wrasse',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:170500'],
#  ['Doridella obscura',
#   'Obscure corambe',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78439'],
#  ['Doriopsilla pharpa',
#   'Lemon drop',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78458'],
#  ['Doris verrucosa',
#   'Sponge slug',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78209'],
#  ['Dorymyrmex flavopectus',
#   'Bi-colored Scrub Cone Ant',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:574909'],
#  ['Doto',
#   'No common name',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:78532'],
#  ['Draba cuneifolia',
#   'Wedgeleaf Whitlow-Wort',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:22874'],
#  ['Draba reptans',
#   'Carolina Whitlow-grass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:22908'],
#  ['Draba smithii',
#   'Smith whitlow-grass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:22911'],
#  ['Dracocephalum parviflorum',
#   'American Dragonhead',
#   1,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:32490'],
#  ['Drilonereis monroi',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:66434'],
#  ['Dromia dormia',
#   'sponge crab, makua-o-ka-lipoa',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:660442'],
#  ['Dryachloa dauca',
#   'Carrot Glass Snail',
#   0,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77320'],
#  ['Drymarchon corais',
#   'Western indigo snake',
#   1,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:174224'],
#  ['Drymarchon melanurus erebennus',
#   'Texas Indigo Snake',
#   0,
#   1,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:683059'],
#  ['Dryopteris cristata',
#   'Crested Wood Fern',
#   1,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17531'],
#  ['Dubautia kenwoodii',
#   'naenae',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:780292'],
#  ['Dubiraphia brunnescens',
#   'Brownish Dubiraphian Riffle Beetle',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:114127'],
#  ['Dulichium arundinaceum',
#   'Pond-Sedge',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40009'],
#  ['Dyschirius politus',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:931764'],
#  ['Eacles imperialis pini',
#   'Pine Imperial Moth',
#   3,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:936251'],
#  ['Eburia stroheckeri',
#   "Strohecker's Ivory-spotted Long-horned Beetle",
#   1,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:702695'],
#  ['Echinacea angustifolia',
#   'Narrow-leaved Coneflower',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:37276'],
#  ['Echinacea paradoxa',
#   'Yellow coneflower',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:37280'],
#  ['Echinargus isola',
#   "Reakirt's Blue",
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:777919'],
#  ['Echinaster brasiliensis',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:157184'],
#  ['Ectopistes migratorius',
#   'Passenger Pigeon',
#   1,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:177132'],
#  ['Ectopleura crocea',
#   'No common name',
#   1,
#   0,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:719101'],
#  ['Ectopria',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:114087'],
#  ['Eidmannella delicata',
#   'A cave obligate spider',
#   1,
#   1,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:855732'],
#  ['Elaenia martinica',
#   'Caribbean Elaenia',
#   2,
#   0,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:178380'],
#  ['Elaeocarpus bifidus',
#   'kalia',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:21506'],
#  ['Elagatis bipinnulata',
#   'Rainbow Runner',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:168738'],
#  ['Elanoides forficatus',
#   'Swallow-tailed Kite',
#   13,
#   7,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:175289'],
#  ['Elaphe guttata',
#   'Eastern Corn Snake',
#   3,
#   1,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:174175'],
#  ['Elaphoglossum',
#   'ekaha, laukahi nunui',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:17773'],
#  ['Elaphoidella',
#   'A cave obligate copepod',
#   0,
#   1,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:88353'],
#  ['Elaphria georgei',
#   "George's midget moth",
#   1,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:938529'],
#  ['Elateridae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:113879'],
#  ['Elatine americana',
#   'American Waterwort',
#   0,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:21405'],
#  ['Elatine brachysperma',
#   'Short-seed Waterwort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:21406'],
#  ['Eleocharis atropurpurea',
#   'Purple spike rush',
#   2,
#   2,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40027'],
#  ['Eleocharis elliptica',
#   'Bog Spikerush',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:502236'],
#  ['Eleocharis geniculata',
#   'Capitate Spikerush',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40046'],
#  ['Eleocharis microcarpa var. filiculmis',
#   'Tiny-fruited Spike-sedge',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:534798'],
#  ['Eleocharis rostellata',
#   'Beaked Spikerush',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40022'],
#  ['Eleotris sandwicensis',
#   'Hawaiian sleeper, oopu akupa',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:171930'],
#  ['Eleutherodactylus antillensis',
#   'Antillean Frog',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173555'],
#  ['Eleutherodactylus monensis',
#   'Mona Island Coqui',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173567'],
#  ['Eleutherodactylus portoricensis',
#   'Puerto Rican Mountain Coqui; Forest Coqui',
#   1,
#   0,
#   'Amphibians',
#   'http://services.itis.gov/?q=tsn:173569'],
#  ['Elgaria coerulea',
#   'Northern Alligator Lizard',
#   2,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:209008'],
#  ['Elgaria panamintina',
#   'Panamint alligator lizard',
#   2,
#   1,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:209029'],
#  ['Elimia albanyensis',
#   'Black-crested Elimia Snail',
#   1,
#   1,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:71876'],
#  ['Elimia boykiniana',
#   'Flaxen Elimia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:71678'],
#  ['Elimia lachryma',
#   'Teardrop Elimia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:567521'],
#  ['Elimia ornata',
#   'Ornate Elimia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:567523'],
#  ['Elimia strigosa',
#   'Brook Elimia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:71871'],
#  ['Elimia troostiana',
#   'Mossy Elimia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:71872'],
#  ['Elimia virginica',
#   'Virginia River Snail',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:71851'],
#  ['Elodea bifoliata',
#   'Two-leaf Waterweed',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:38940'],
#  ['Elymus villosus var. villosus',
#   'Hairy Wild-rye',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:531424'],
#  ['Elymus X pseudorepens',
#   "Rydberg's Wild-rye",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:502274'],
#  ['Emoia lawesii',
#   'Lawes skink; pili oua',
#   1,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:173984'],
#  ['Emoia slevini',
#   "Slevin's Skink",
#   2,
#   0,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:173989'],
#  ['Empetrichthys latos latos',
#   'Pahrump poolfish',
#   1,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:647756'],
#  ['Empetrum nigrum',
#   'Black Crowberry',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:23743'],
#  ['Empidonax fulvifrons pygmaeus',
#   'Northern Buff-breasted Flycatcher',
#   1,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:178353'],
#  ['Empidonax traillii extimus',
#   'Southwestern Willow Flycatcher',
#   6,
#   4,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:712529'],
#  ['Empidonax wrightii',
#   'Gray Flycatcher',
#   1,
#   1,
#   'Birds',
#   'http://services.itis.gov/?q=tsn:178347'],
#  ['Enallagma antennatum',
#   'Rainbow Bluet',
#   3,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102103'],
#  ['Enallagma aspersum',
#   'Azure bluet',
#   2,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102126'],
#  ['Enallagma boreale',
#   'Boreal Bluet',
#   3,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102121'],
#  ['Enallagma carunculatum',
#   'Tule bluet',
#   4,
#   4,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102123'],
#  ['Enallagma dubium',
#   'Burgundy bluet',
#   3,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102110'],
#  ['Enallagma minusculum',
#   'Little bluet',
#   3,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:181183'],
#  ['Enallagma traviatum',
#   'Slender Bluet',
#   3,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102116'],
#  ['Enallagma vernale',
#   'Northern Bluet',
#   3,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:102131'],
#  ['Enaphalodes archboldi',
#   'Archbold Scrub Long-horned Beetle',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:704721'],
#  ['Enchelycore nigricans',
#   'Viper Moray',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:161180'],
#  ['Encoptolophus subgracilis',
#   'A Grasshopper',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:658175'],
#  ['Enneapterygius atriceps',
#   'Hawaiian triplefin',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:638443'],
#  ['Enochrus diffusus',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:112980'],
#  ['Enoplometopidae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:203639'],
#  ['Ensis directus',
#   'Common Razor Clam',
#   2,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:81022'],
#  ['Entodesma beana',
#   'Pearly lyonsia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:81915'],
#  ['Entosphenus minimus',
#   'Miller Lake Lamprey',
#   1,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:914063'],
#  ['Entosphenus similis',
#   'Klamath River Lamprey',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:914058'],
#  ['Eocyzicus concavus',
#   'No Common Name',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:83824'],
#  ['Epeolus ainsliei',
#   'A Cuckoo Bee',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:694356'],
#  ['Epeolus rugosus',
#   'Punctate Central Florida Cuckoo Bee',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:694410'],
#  ['Ephemerella catawba',
#   'no common name',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101262'],
#  ['Ephemerella excrucians',
#   'Pale Morning Dun',
#   3,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101276'],
#  ['Ephemerella invaria',
#   '--',
#   1,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:101282'],
#  ['Epifungium ulu',
#   'fungiid wentletrap',
#   1,
#   0,
#   'Mollusks',
#   'http://www.marinespecies.org/rest/AphiaRecordByAphiaID/523767'],
#  ['Epinephelus guttatus',
#   'Red Hind',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:167700'],
#  ['Epinephelus morio',
#   'Red grouper',
#   3,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:167702'],
#  ['Epinephelus niveatus',
#   'Snowy Grouper',
#   1,
#   1,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:167705'],
#  ['Epinephelus quernus',
#   'Hawaiian grouper, hapuu',
#   1,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:167707'],
#  ['Epioblasma capsaeformis',
#   'Oyster mussel',
#   4,
#   2,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80306'],
#  ['Epioblasma metastriata',
#   'Upland Combshell',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80321'],
#  ['Epioblasma othcaloogensis',
#   'Southern Acornshell',
#   2,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80328'],
#  ['Epioblasma rangiana',
#   'Northern Riffleshell',
#   7,
#   4,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:983763'],
#  ['Epioblasma triquetra',
#   'Snuffbox',
#   17,
#   12,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80345'],
#  ['Epirrita autumnata henshawi',
#   'The November moth',
#   1,
#   0,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:943684'],
#  ['Epitheca petechialis',
#   'Dot-winged Baskettail - A Dragonfly',
#   1,
#   2,
#   'Other Invertebrates',
#   'http://services.itis.gov/?q=tsn:593050'],
#  ['Epitheca spinosa',
#   'Robust baskettail',
#   4,
#   3,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:593052'],
#  ['Epithelantha bokei',
#   "Boke's button cactus",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:19793'],
#  ['Eragrostis reptans',
#   'Creeping Lovegrass',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40759'],
#  ['Eragrostis variabilis',
#   'kawelu',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:40739'],
#  ['Erastria coloraria',
#   'Broad-lined catopyrrha',
#   4,
#   2,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:941899'],
#  ['Ereboporus naturaconservatus',
#   'Nature Conservancy diving beetle',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:814615'],
#  ['Eremarionta morongoana',
#   'Morongo (=Colorado) Desertsnail',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:77724'],
#  ['Eretmochelys imbricata',
#   'Hawksbill Sea Turtle',
#   18,
#   7,
#   'Reptiles',
#   'http://services.itis.gov/?q=tsn:173836'],
#  ['Ericameria nauseosa var. nauseosa',
#   'Rubber Rabbitbrush',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:566645'],
#  ['Ericameria parryi var. howardii',
#   "Parry's Rabbitbrush",
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:531195'],
#  ['Erichsonella filiformis',
#   'Seaweed sowbug',
#   1,
#   0,
#   'Crustaceans',
#   'http://services.itis.gov/?q=tsn:92619'],
#  ['Erigeron flagellaris',
#   'Trailing Fleabane',
#   1,
#   0,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:35865'],
#  ['Erigeron kachinensis',
#   'Kachina daisy',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:35884'],
#  ['Erigeron vetensis',
#   'Early Blue-top Fleabane',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:35970'],
#  ['Erimonax monachus',
#   'Spotfin chub',
#   5,
#   2,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:689041'],
#  ['Erimystax insignis',
#   'Blotched Chub',
#   5,
#   2,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:163823'],
#  ['Eriocaulon koernickianum',
#   'Small-headed pipewort',
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:39199'],
#  ['Eriocaulon texense',
#   'Texas Pipewort',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:39203'],
#  ['Eriochloa michauxii',
#   'Longleaf Cupgrass',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:41726'],
#  ['Eriogonum brevicaule var. brevicaule',
#   'Short-stem Wild-buckwheat',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:195428'],
#  ['Eriogonum crosbyae',
#   "Crosby's Buckwheat",
#   1,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:195635'],
#  ['Eriogonum greggii',
#   "Gregg's wild-buckwheat",
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:21145'],
#  ['Eriogonum hemipterum var. hemipterum',
#   'Chisos Mountains wild-buckwheat',
#   0,
#   1,
#   'Plants',
#   'http://services.itis.gov/?q=tsn:823902'],
#  ['Erotelis smaragdus',
#   'Emerald Sleeper',
#   3,
#   0,
#   'Fish',
#   'http://services.itis.gov/?q=tsn:171878'],
#  ['Erotylidae',
#   'NA',
#   0,
#   1,
#   'Insects',
#   'http://services.itis.gov/?q=tsn:114321'],
#  ['Ervilia concentrica',
#   'Concentric ervilia',
#   1,
#   0,
#   'Mollusks',
#   'http://services.itis.gov/?q=tsn:80995'],
#  ...]
