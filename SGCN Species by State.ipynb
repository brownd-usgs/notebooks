# %% [markdown]
# # SGCN species by state

# %% [markdown]
# This notebook provides the essential queries and shows a rough output for the content that needs to go online in the SWAP application for the [state lists](https://www1.usgs.gov/csas/swap/state_list.html). When the application is updated, it would be desirable to change the architecture such that the state lists respond to an actual query parameter in the URL as demonstrated by using an input variable here in the notebook.
#
# I messed around with the "interactive" features for iPython here, but I notice those do not render when the notebook is accessed through GitHub. Bummer! If you want to actually select a particular state for this demo, you will need to run it locally through Jupyter or load it into an online system like Wakari (presumably, haven't tried it).

# %%
import requests
from ipywidgets import interactive
import ipywidgets as widgets
from IPython.display import display
import pandas as pd

# %%
#Class to render tables
class ListTable(list):
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
#Get the states currently available in the SGCN data and build a list
sgcnStatesQuery = "https://gc2.mapcentia.com/api/v1/sql/bcb?q=SELECT%20DISTINCT%20state%20FROM%20sgcn%20ORDER%20BY%20state"
sgcnStates = requests.get(sgcnStatesQuery).json()
sgcnStateList = []
for feature in sgcnStates['features']:
    sgcnStateList.append(feature['properties']['state'])
# Set up a select widget for use with interactive below to call up a particular state
stateSelectWidget = widgets.Select(options=sgcnStateList)

# %%
# Set up a function to get the state data and write them out into a table
def getSGCNforState(stateName):
    GC2SQLURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?q=SELECT%20*%20FROM%20sgcn%20WHERE%20state%20=%20%27"+stateName+"%27%20ORDER%20BY%20scientificname_accepted"
    GC2SQLData = requests.get(GC2SQLURL).json()

    speciesList = []
    tableStateList = ListTable()
    tableStateList.append(['Scientific Name', 'Common Name', '2005', '2015', 'Taxonomic Group'])

    for feature in GC2SQLData['features']:

        # If the final accepted name from the taxonomic authority is not in the data, then use the originally submitted name and flag it with a note
        if len(feature['properties']['scientificname_accepted']) > 0:
            scientificname_display = feature['properties']['scientificname_accepted']
        else:
            scientificname_display = feature['properties']['scientificname_submitted']
            
        if scientificname_display in speciesList:
            x = 1
        else:
            speciesList.append(scientificname_display)
            tableStateList.append([scientificname_display, feature['properties']['commonname_submitted'], feature['properties']['taxonomicgroup_submitted']])
        
    display(stateName)
    display(tableStateList)    

# Launch the state select widget for making a selection (It seems to default to a selection, which fires the function, but that's okay for demo purposes.)
getState = widgets.interactive(getSGCNforState, stateName=stateSelectWidget)
display(getState)
# Out:
# 'Alaska'
# [['Scientific Name', 'Common Name', '2005', '2015', 'Taxonomic Group'],
#  ['Clethrionomys gapperi wrangeli',
#   'southern red-backed vole, Wrangell Island',
#   'Mammals'],
#  ['no scientific name', 'Cave-dwelling species', 'Other Invertebrates'],
#  ['Lemmus trimucronatus harroldi', 'brown lemming, Nunivak Island', 'Mammals'],
#  ['Cottid Family', 'Forage fish', 'Fish'],
#  ['Clethrionomys rutilus orca', 'northern red-backed vole', 'Mammals'],
#  ['Clethrionomys rutilus insularis', 'northern red-backed vole', 'Mammals'],
#  ['Clethrionomys rutilus glacialis',
#   'northern red-backed vole, Glacier Bay',
#   'Mammals'],
#  ['Clethrionomys rutilus albiventer',
#   'northern red-backed vole, St. Lawrence Island',
#   'Mammals'],
#  ['Clethrionomys gapperi phaeus', 'southern red-backed vole', 'Mammals'],
#  ['Rhamphocottid Family', 'Forage fish', 'Fish'],
#  ['Phyciodes pratensis totchone', 'Field crescent', 'Insects'],
#  ['Stichaeid Family', 'Forage fish', 'Fish'],
#  ['Pholid Family', 'Forage fish', 'Fish'],
#  ['Peromyscus keeni sitkensis', 'forest deer mouse', 'Mammals'],
#  ['Peromyscus keeni oceanicus', 'forest deer mouse', 'Mammals'],
#  ['Peromyscus keeni macrorhinus', 'forest deer mouse', 'Mammals'],
#  ['Peromyscus keeni hylaeus', 'forest deer mouse', 'Mammals'],
#  ['Peromyscus keeni algidus', 'forest deer mouse', 'Mammals'],
#  ['Vertigo hannai', "Hanna's vertigo", 'Mollusks'],
#  ['Microtus pennsylvanicus admiraltiae',
#   'meadow vole, Admiralty Island',
#   'Mammals'],
#  ['Microtus oeconomus yakutatensis', 'tundra vole, Yakutat', 'Mammals'],
#  ['Microtus oeconomus unalascensis', 'tundra vole, Unalaska', 'Mammals'],
#  ['Microtus oeconomus sitkensis', 'tundra vole, Sitka', 'Mammals'],
#  ['Microtus oeconomus punukensis', 'tundra vole, Punuk Island', 'Mammals'],
#  ['Microtus oeconomus popofensis', 'tundra vole, Shumagin Island', 'Mammals'],
#  ['Microtus oeconomus innuitus',
#   'tundra vole, St. Lawrence Island',
#   'Mammals'],
#  ['Microtus oeconomus amakensis', 'tundra vole, Amak Island', 'Mammals'],
#  ['Microtus longicaudus littoralis', 'long-tailed vole', 'Mammals'],
#  ['Microtus abbreviatus abbreviatus', 'insular vole, Hall Island', 'Mammals'],
#  ['Lemmus trimucronatus nigripes', 'brown lemming, blackfooted', 'Mammals'],
#  ['Hemipterid Family', 'Forage fish', 'Fish'],
#  ['Dicrostonyx groenlandicus unalascensis',
#   'collared lemming, Unalaska',
#   'Mammals'],
#  ['Dicrostonyx groenlandicus stevensoni',
#   "collared lemming, Stevenson's",
#   'Mammals'],
#  ['Dicrostonyx groenlandicus peninsulae', 'collared lemming', 'Mammals'],
#  ['Dicrostonyx groenlandicus exsul',
#   'collared lemming, St. Lawrence Island',
#   'Mammals'],
#  ['Acanthis hornemanni', 'Hoary Redpoll', 'Birds'],
#  ['Accipiter gentilis', 'Northern Goshawk', 'Birds'],
#  ['Accipiter gentilis atricapillus', 'Northern Goshawk', 'Birds'],
#  ['Accipiter gentilis laingi', 'Queen Charlotte Northern Goshawk', 'Birds'],
#  ['Accipiter striatus', 'Sharp-shinned Hawk', 'Birds'],
#  ['Acentrella feropagus', 'A mayfly', 'Insects'],
#  ['Acipenser medirostris', 'green sturgeon', 'Fish'],
#  ['Acipenser transmontanus', 'white sturgeon', 'Fish'],
#  ['Actitis hypoleucos', 'Common Sandpiper', 'Birds'],
#  ['Aegolius acadicus', 'Northern Saw-Whet', 'Birds'],
#  ['Aegolius funereus', 'Boreal Owl', 'Birds'],
#  ['Aethia cristatella', 'Crested Auklet', 'Birds'],
#  ['Aethia pusilla', 'Least Auklet', 'Birds'],
#  ['Aethia pygmaea', 'Whiskered Auklet', 'Birds'],
#  ['Agelaius phoeniceus', 'Red-winged Blackbird', 'Birds'],
#  ['Alaskaperla ovibovis', 'A stonefly', 'Insects'],
#  ['Alauda arvensis', 'Sky Lark', 'Birds'],
#  ['Alle alle', 'Dovekie', 'Birds'],
#  ['Ambystoma gracile', 'Northwestern salamander', 'Amphibians'],
#  ['Ambystoma macrodactylum', 'Long-toed salamander', 'Amphibians'],
#  ['Ammodytes hexapterus', 'Pacific sand lance', 'Fish'],
#  ['Anaxyrus boreas', 'Western toad', 'Amphibians'],
#  ['Annelida', 'Leches, earthworms, bristle worms', 'Other Invertebrates'],
#  ['Anodonta beringiana', 'Yukon floater', 'Mollusks'],
#  ['Anodonta kennerlyi', 'Western floater', 'Mollusks'],
#  ['Anser albifrons elgasi', 'Tule Whitefronted Goose', 'Birds'],
#  ['Anthocharis sara alaskensis', 'Alaskan orange tip', 'Insects'],
#  ['Aphriza virgata', 'Surfbird', 'Birds'],
#  ['Aquila chrysaetos', 'Golden Eagle', 'Birds'],
#  ['Ardea herodias fannini', 'Pacific Great Blue Heron', 'Birds'],
#  ['Arenaria melanocephala', 'Black Turnstone', 'Birds'],
#  ['Arthropoda', 'Crustaceans, Spiders, Insects', 'Other Invertebrates'],
#  ['Asio flammeus', 'Short-eared Owl', 'Birds'],
#  ['Balaena mysticetus', 'bowhead, Western Arctic', 'Mammals'],
#  ['Balaenoptera acutorostrata', 'minke whale, Northern', 'Mammals'],
#  ['Balaenoptera borealis', 'sei whale, North Pacific', 'Mammals'],
#  ['Balaenoptera musculus', 'blue whale, North Pacific', 'Mammals'],
#  ['Balaenoptera physalus', 'fin whale, Northeast Pacific', 'Mammals'],
#  ['Bartramia longicauda', 'Upland Sandpiper', 'Birds'],
#  ['Berardius bairdii', "Baird's beaked whale", 'Mammals'],
#  ['Bison bison', 'Wood Bison', 'Mammals'],
#  ['Bivalvia', 'Clams and Mussels', 'Mollusks'],
#  ['Boloria astarte distincta', 'Astarte fritillary', 'Insects'],
#  ['Boloria eunomia denali', 'Bog fritillary', 'Insects'],
#  ['Bombus occidentalis', 'Western bumblebee', 'Insects'],
#  ['Bombycilla garrulus', 'Bohemian Waxwing', 'Birds'],
#  ['Boreogadus saida', 'Arctic cod', 'Fish'],
#  ['Botaurus lentiginosus', 'American Bittern', 'Birds'],
#  ['Brachycercus harrisella', 'A mayfly', 'Insects'],
#  ['Brachyramphus brevirostris', "Kittlitz's Murrelet", 'Birds'],
#  ['Brachyramphus marmoratus', 'Marbled Murrelet', 'Birds'],
#  ['Branta hutchinsii leucopareia', 'Aleutian Canada Goose', 'Birds'],
#  ['Bubo scandiacus', 'Snowy Owl', 'Birds'],
#  ['Bubo virginianus', 'Great Horned Owl', 'Birds'],
#  ['Buteo jamaicensis alascensis', 'Red-tailed Hawk', 'Birds'],
#  ['Buteo lagopus', 'Rough-legged Hawk', 'Birds'],
#  ['Buteo swainsoni', "Swainson's Hawk", 'Birds'],
#  ['Calcarius pictus', "Smith's Longspur", 'Birds'],
#  ['Calidris acuminata', 'Sharp-tailed Sandpiper', 'Birds'],
#  ['Calidris alba', 'Sanderling', 'Birds'],
#  ['Calidris alpina', 'Dunlin', 'Birds'],
#  ['Calidris alpina arcticola', 'Arctic Dunlin', 'Birds'],
#  ['Calidris alpina pacifica', 'Pacific Dunlin', 'Birds'],
#  ['Calidris bairdii', "Baird's Sandpiper", 'Birds'],
#  ['Calidris canutus', 'Red Knot', 'Birds'],
#  ['Calidris canutus roselaari', 'Red Knot', 'Birds'],
#  ['Calidris ferruginea', 'Curlew sandpiper', 'Birds'],
#  ['Calidris fuscicollis', 'White-rumped Sandpiper', 'Birds'],
#  ['Calidris himantopus', 'Stilt Sandpiper', 'Birds'],
#  ['Calidris mauri', 'Western Sandpiper', 'Birds'],
#  ['Calidris ptilocnemis couesi', 'Rock Sandpiper, Aleutians', 'Birds'],
#  ['Calidris ptilocnemis ptilocnemis', 'Rock Sandpiper, Pribilofs', 'Birds'],
#  ['Calidris ptilocnemis tschuktschorum',
#   'Rock Sandpiper, Bering Sea',
#   'Birds'],
#  ['Calidris pusilla', 'Semipalmated Sandpiper', 'Birds'],
#  ['Calidris subminuta', 'Long-toed Stint', 'Birds'],
#  ['Calidris temminckii', "Temminck's Stint", 'Birds'],
#  ['Callorhinus ursinus', 'northern fur seal', 'Mammals'],
#  ['Calypte anna', "Anna's Hummingbird", 'Birds'],
#  ['Canis lupus ligoni', 'gray wolf, Alexander Archipelago', 'Mammals'],
#  ['Cardellina pusilla', "Wilson's Warbler", 'Birds'],
#  ['Caretta caretta', 'Loggerhead seaturtle', 'Reptiles'],
#  ['Castor canadensis', 'beaver, Admiralty', 'Mammals'],
#  ['Catharus guttatus', 'Hermit Thrush', 'Birds'],
#  ['Catharus minimus', 'Gray-cheeked Thrush', 'Birds'],
#  ['Catharus ustulatus', "Swainson's Thrush", 'Birds'],
#  ['Catostomus catostomus', 'longnose sucker', 'Fish'],
#  ['Cepphus columba', 'Pigeon Guillemot', 'Birds'],
#  ['Cepphus grylle', 'Black Guillemot', 'Birds'],
#  ['Certhia americana', 'Brown Creeper', 'Birds'],
#  ['Chaetura vauxi', "Vaux's Swift", 'Birds'],
#  ['Charadrius mongolus', 'Mongolian Plover', 'Birds'],
#  ['Charadrius mongolus stegmanni', 'Eastern Mongolian Plover', 'Birds'],
#  ['Charadrius morinellus', 'Eurasian Dotterel', 'Birds'],
#  ['Charadrius vociferus', 'Killdeer', 'Birds'],
#  ['Chelonia mydas', 'Green seaturtle', 'Reptiles'],
#  ['Chroicocephalus ridibundus', 'Black-headed Gull', 'Birds'],
#  ['Cinclus mexicanus', 'American Dipper', 'Birds'],
#  ['Circus cyaneus', 'Northern Harrier', 'Birds'],
#  ['Cladocera', 'Water fleas', 'Insects'],
#  ['Clangula hyemalis', 'Long-tailed Duck', 'Birds'],
#  ['Clinocottus acuticeps', 'sharpnose sculpin', 'Fish'],
#  ['Colaptes auratus', 'Northern Flicker', 'Birds'],
#  ['Contopus cooperi', 'Olive-sided Flycatcher', 'Birds'],
#  ['Contopus sordidulus', 'Western Wood-Pewee', 'Birds'],
#  ['Coregonus laurettae', 'Bering cisco', 'Fish'],
#  ['Coregonus nasus', 'broad whitefish', 'Fish'],
#  ['Coregonus pidschian', 'humpback whitefish', 'Fish'],
#  ['Corvus brachyrhynchos', 'American Crow', 'Birds'],
#  ['Corvus caurinus', 'Northwestern Crow', 'Birds'],
#  ['Cottus aleuticus', 'coastrange sculpin', 'Fish'],
#  ['Cottus asper', 'prickly sculpin', 'Fish'],
#  ['Cottus cognatus', 'slimy sculpin', 'Fish'],
#  ['Couesius plumbeus', 'lake chub', 'Fish'],
#  ['Cryptochiton stelleri', 'Gumboot chiton', 'Other Invertebrates'],
#  ['Cyanocitta stelleri', "Steller's Jay", 'Birds'],
#  ['Cymatogaster aggregata', 'shiner perch', 'Fish'],
#  ['Cypseloides niger', 'Black Swift', 'Birds'],
#  ['Cypseloides niger borealis', 'Black Swift', 'Birds'],
#  ['Dallia pectoralis', 'Alaska blackfish', 'Fish'],
#  ['Delphinapterus leucas', 'beluga whale, Cook Inlet', 'Mammals'],
#  ['Dendragapus obscurus', 'Blue Grouse', 'Birds'],
#  ['Dermochelys coriacea', 'Leatherback seaturtle', 'Reptiles'],
#  ['Dicrostonyx groenlandicus', 'collared lemming', 'Mammals'],
#  ['Emberiza rustica', 'Rustic Bunting', 'Birds'],
#  ['Empidonax difficilis', 'Pacific-slope Flycatcher', 'Birds'],
#  ['Empidonax hammondii', "Hammond's Flycatcher", 'Birds'],
#  ['Enhydra lutris', 'sea otter', 'Mammals'],
#  ['Enhydra lutris kenyoni',
#   'northern sea otter, Southwest Alaska population',
#   'Mammals'],
#  ['Entosphenus tridentatus', 'Pacific lamprey', 'Fish'],
#  ['Ephemerella excrucians', 'A mayfly', 'Insects'],
#  ['Ephemeroptera', 'Mayflies', 'Insects'],
#  ['Eptesicus fuscus', 'big brown bat', 'Mammals'],
#  ['Erignathus barbatus', 'bearded seal', 'Mammals'],
#  ['Eschrichtius robustus', 'gray whale, Eastern Pacific', 'Mammals'],
#  ['Eubalaena glacialis', 'northern right whale, North Pacific', 'Mammals'],
#  ['Eumetopias jubatus',
#   "Steller's sea lion, Eastern Alaska Population",
#   'Mammals'],
#  ['Euphagus carolinus', 'Rusty Blackbird', 'Birds'],
#  ['Falcipennis canadensis isleibi', 'Prince of Wales Spruce Grouse', 'Birds'],
#  ['Falco columbarius', 'Merlin', 'Birds'],
#  ['Falco columbarius suckleyi', 'Black Merlin', 'Birds'],
#  ['Falco peregrinus', 'Peregrine Falcon', 'Birds'],
#  ['Falco peregrinus anatum', 'American Peregrine Falcon', 'Birds'],
#  ['Falco peregrinus pealei', "Peale's Peregrine Falcon", 'Birds'],
#  ['Falco peregrinus tundrius', 'Arctic Peregrine Falcon', 'Birds'],
#  ['Falco rusticolus', 'Gyrfalcon', 'Birds'],
#  ['Fossaria truncatula', 'Attenuate fossaria', 'Mollusks'],
#  ['Fregata magnificens', 'Magnificent Frigatebird', 'Birds'],
#  ['Fringilla montifringilla', 'Brambling', 'Birds'],
#  ['Fulica americana', 'American Coot', 'Birds'],
#  ['Gallinago delicata', "Wilson's Snipe", 'Birds'],
#  ['Gallinago gallinago', 'Common Snipe', 'Birds'],
#  ['Gasterosteus aculeatus', 'threespine stickleback', 'Fish'],
#  ['Gastropoda', 'Snails, Slugs, Limpets', 'Mollusks'],
#  ['Gavia adamsii', 'Yellow-billed Loon', 'Birds'],
#  ['Gavia arctica', 'Arctic Loon', 'Birds'],
#  ['Gavia arctica viridigularis', 'Green-throated Arctic Loon', 'Birds'],
#  ['Gavia immer', 'Common Loon', 'Birds'],
#  ['Gavia pacifica', 'Pacific Loon', 'Birds'],
#  ['Gavia stellata', 'Red-throated Loon', 'Birds'],
#  ['Geothlypis tolmiei', "MacGillivray's Warbler", 'Birds'],
#  ['Glaucidium gnoma', 'Northern Pygmy-Owl', 'Birds'],
#  ['Glaucomys sabrinus alpinus', 'northern flying squirrel', 'Mammals'],
#  ['Glaucomys sabrinus griseifrons',
#   'northern flying squirrel, Prince of Wales',
#   'Mammals'],
#  ['Gulo gulo katschemakensis', 'wolverine, Kenai', 'Mammals'],
#  ['Haematopus bachmani', 'Black Oystercatcher', 'Birds'],
#  ['Haliaeetus albicilla', 'White-tailed Eagle', 'Birds'],
#  ['Haliaeetus leucocephalus', 'Bald Eagle', 'Birds'],
#  ['Haliaeetus leucocephalus washingtoniensis', 'Northern Bald Eagle', 'Birds'],
#  ['Haliotis kamtschatkana', 'Pinto (Northern) abalone', 'Mollusks'],
#  ['Hirundo rustica', 'Barn Swallow', 'Birds'],
#  ['Histriophoca fasciata', 'ribbon seal', 'Mammals'],
#  ['Hydroprogne caspia', 'Caspian Tern', 'Birds'],
#  ['Hypomesus olidus', 'pond smelt', 'Fish'],
#  ['Hypomesus pretiosus', 'surf smelt', 'Fish'],
#  ['Isocapnia agassizi', 'A stonefly', 'Insects'],
#  ['Isoperla decolorata', 'A stonefly', 'Insects'],
#  ['Isoperla katmaiensis', 'A stonefly', 'Insects'],
#  ['Isoperla sordida', 'A stonefly', 'Insects'],
#  ['Ixoreus naevius', 'Varied Thrush', 'Birds'],
#  ['Junco hyemalis', 'Dark-eyed Junco', 'Birds'],
#  ['Katharina tunicata', 'Black Katy chiton', 'Other Invertebrates'],
#  ['Lagopus muta atkhensis', 'Turners Rock Ptarmigan', 'Birds'],
#  ['Lagopus muta evermanni', "Evermann's Rock Ptarmigan", 'Birds'],
#  ['Lagopus muta townsendi', "Townsend's Rock Ptarmigan", 'Birds'],
#  ['Lampetra ayresii', 'river lamprey', 'Fish'],
#  ['Lampetra richardsoni', 'western brook lamprey', 'Fish'],
#  ['Lanius excubitor', 'Northern Shrike', 'Birds'],
#  ['Larus californicus', 'California Gull', 'Birds'],
#  ['Larus delawarensis', 'Ring-billed Gull', 'Birds'],
#  ['Larus hyperboreus', 'Glaucous Gull', 'Birds'],
#  ['Larus schistisagus', 'Slaty-backed Gull', 'Birds'],
#  ['Lasionycteris noctivagans', 'silver-haired bat', 'Mammals'],
#  ['Leiothlypis peregrina', 'Tennessee Warbler', 'Birds'],
#  ['Lemmus trimucronatus', 'brown lemming', 'Mammals'],
#  ['Lepidochelys olivacea', 'Olive Ridley seaturtle', 'Reptiles'],
#  ['Leptocottus armatus', 'Pacific staghorn sculpin', 'Fish'],
#  ['Lepus othus', 'tundra hare', 'Mammals'],
#  ['Lethenteron alaskense', 'Alaskan brook lamprey', 'Fish'],
#  ['Lethenteron camtschaticum', 'Arctic lamprey', 'Fish'],
#  ['Lethenteron kessleri', 'Siberian brook lamprey', 'Fish'],
#  ['Leucosticte tephrocotis', 'Gray-crowned Rosy-Finch', 'Birds'],
#  ['Limnodromus griseus', 'Short-billed Dowitcher', 'Birds'],
#  ['Limnodromus griseus caurinus', 'Short-billed Dowitcher', 'Birds'],
#  ['Limosa fedoa', 'Marbled Godwit', 'Birds'],
#  ['Limosa fedoa beringiae', 'Beringian Marbled Godwit', 'Birds'],
#  ['Limosa haemastica', 'Hudsonian Godwit', 'Birds'],
#  ['Limosa lapponica', 'Bar-tailed Godwit', 'Birds'],
#  ['Limosa lapponica baueri', 'Bar-tailed Godwit', 'Birds'],
#  ['Limosa limosa', 'Black-tailed Godwit', 'Birds'],
#  ['Lithobates sylvaticus', 'Wood frog', 'Amphibians'],
#  ['Lontra canadensis mira', 'river otter, Prince of Wales', 'Mammals'],
#  ['Loxia curvirostra', 'Red Crossbill', 'Birds'],
#  ['Loxia leucoptera', 'White-winged Crossbill', 'Birds'],
#  ['Luscinia calliope', 'Siberian Rubythroat', 'Birds'],
#  ['Luscinia svecica', 'Bluethroat', 'Birds'],
#  ['Lymnaea atkaensis', 'Frigid lymnaea', 'Mollusks'],
#  ['Mallotus villosus', 'capelin', 'Fish'],
#  ['Margaritifera falcata', 'Western pearl shell', 'Mollusks'],
#  ['Marmota broweri', 'Alaska marmot', 'Mammals'],
#  ['Marmota caligata caligata', 'hoary marmot, Glacier Bay', 'Mammals'],
#  ['Martes americana caurina', 'marten', 'Mammals'],
#  ['Martes americana kenaiensis', 'marten, Kenai', 'Mammals'],
#  ['Megaceryle alcyon', 'Belted Kingfisher', 'Birds'],
#  ['Megaptera novaeangliae',
#   'humpback whale, Western and Central North Pacific',
#   'Mammals'],
#  ['Megascops kennicottii', 'Western Screech-Owl', 'Birds'],
#  ['Melanitta fusca deglandi', 'White-winged Scoter', 'Birds'],
#  ['Melanitta nigra americana', 'Black Scoter', 'Birds'],
#  ['Melanitta perspicillata', 'Surf Scoter', 'Birds'],
#  ['Melospiza melodia maxima', 'Giant Song Sparrow', 'Birds'],
#  ['Melospiza melodia sanaka', 'Amak Island Song Sparrow', 'Birds'],
#  ['Mesocapnia bergi', 'A stonefly', 'Insects'],
#  ['Mesoplodon stejnegeri', "Stejneger's beaked whale", 'Mammals'],
#  ['Microtus abbreviatus', 'insular vole', 'Mammals'],
#  ['Microtus longicaudus', 'long-tailed vole', 'Mammals'],
#  ['Microtus miurus', 'singing vole', 'Mammals'],
#  ['Microtus oeconomus', 'tundra vole, Montague Island', 'Mammals'],
#  ['Microtus pennsylvanicus', 'meadow vole', 'Mammals'],
#  ['Microtus xanthognathus', 'yellow-cheeked vole (Taiga vole)', 'Mammals'],
#  ['Mirounga angustirostris', 'elephant seal', 'Mammals'],
#  ['Molothrus ater', 'Brown-headed Cowbird', 'Birds'],
#  ['Motacilla alba', 'White Wagtail', 'Birds'],
#  ['Motacilla alba lugens', 'Black-backed Wagtail', 'Birds'],
#  ['Motacilla tschutschensis', 'Eastern Yellow Wagtail', 'Birds'],
#  ['Mustela erminea alascensis', 'ermine', 'Mammals'],
#  ['Mustela erminea celenda', 'ermine, Prince of Wales', 'Mammals'],
#  ['Mustela erminea initis', 'ermine', 'Mammals'],
#  ['Mustela erminea kadiacensis', 'ermine, Kodiak', 'Mammals'],
#  ['Mustela erminea salva', 'ermine', 'Mammals'],
#  ['Mustela erminea seclusa', 'ermine, Suemez Island', 'Mammals'],
#  ['Myadestes townsendi', "Townsend's Solitaire", 'Birds'],
#  ['Myctophidae', 'Forage fish', 'Fish'],
#  ['Myodes gapperi', "southern red-backed vole, Gapper's", 'Mammals'],
#  ['Myodes rutilus', 'northern red-backed vole', 'Mammals'],
#  ['Myotis californicus', 'California myotis', 'Mammals'],
#  ['Myotis keenii', "Keen's myotis", 'Mammals'],
#  ['Myotis lucifugus', 'little brown myotis', 'Mammals'],
#  ['Myotis volans longicrus', 'long-legged myotis', 'Mammals'],
#  ['Myoxocephalus quadricornis', 'fourhorn sculpin', 'Fish'],
#  ['Nematoda', 'Round, whip, lung, hook, and eel', 'Other Invertebrates'],
#  ['Nemoura normani', 'A stonefly', 'Insects'],
#  ['Numenius borealis', 'Eskimo Curlew', 'Birds'],
#  ['Numenius phaeopus', 'Whimbrel', 'Birds'],
#  ['Numenius tahitiensis', 'Bristle-thighed Curlew', 'Birds'],
#  ['Oceanodroma furcata', 'Fork-tailed Storm-Petrel', 'Birds'],
#  ['Oceanodroma furcata furcata', 'Fork-tailed Storm-Petrel', 'Birds'],
#  ['Oceanodroma furcata plumbea', 'Fork-tailed Storm-Petrel', 'Birds'],
#  ['Oceanodroma leucorhoa', "Leach's Storm-Petrel", 'Birds'],
#  ['Oceanodroma leucorhoa leucorhoa', "Leach's Storm-Petrel", 'Birds'],
#  ['Ochotona collaris', 'collared pika', 'Mammals'],
#  ['Odobenus rosmarus', 'walrus', 'Mammals'],
#  ['Odonata', 'Dragonflies and Damselflies', 'Insects'],
#  ['Oeneis alpina', 'Eskimo arctic', 'Insects'],
#  ['Oeneis uhleri cairnesi', "Uhler's arctic", 'Insects'],
#  ['Onychoprion aleuticus', 'Aleutian Tern', 'Birds'],
#  ['Orcinus orca', 'killer whale', 'Mammals'],
#  ['Osmerus mordax', 'rainbow smelt', 'Fish'],
#  ['Pandion haliaetus', 'Osprey', 'Birds'],
#  ['Pandion haliaetus carolinensis', 'Osprey', 'Birds'],
#  ['Parkesia noveboracensis', 'Northern Waterthrush', 'Birds'],
#  ['Passerella iliaca', 'Fox Sparrow', 'Birds'],
#  ['Patagioenas fasciata', 'Band-tailed Pigeon', 'Birds'],
#  ['Percopsis omiscomaycus', 'trout-perch', 'Fish'],
#  ['Peromyscus keeni', "forest deer mouse, Keen's mouse", 'Mammals'],
#  ['Petrochelidon pyrrhonota', 'Cliff Swallow', 'Birds'],
#  ['Phalacrocorax auritus', 'Double-crested Cormorant', 'Birds'],
#  ['Phalacrocorax pelagicus', 'Pelagic Cormorant', 'Birds'],
#  ['Phalacrocorax penicillatus', "Brandt's Cormorant", 'Birds'],
#  ['Phalacrocorax urile', 'Red-faced Cormorant', 'Birds'],
#  ['Phalaropus fulicarius', 'Red Phalarope', 'Birds'],
#  ['Phalaropus lobatus', 'Red-necked Phalarope', 'Birds'],
#  ['Philomachus pugnax', 'Ruff', 'Birds'],
#  ['Phoca largha', 'spotted seal', 'Mammals'],
#  ['Phoca vitulina richardii', 'harbor seal , Pacific', 'Mammals'],
#  ['Phocoena phocoena', 'harbor porpoise', 'Mammals'],
#  ['Phoebastria albatrus', 'Short-tailed Albatross', 'Birds'],
#  ['Phoebastria immutabilis', 'Laysan Albatross', 'Birds'],
#  ['Phoebastria nigripes', 'Black-footed Albatross', 'Birds'],
#  ['Phylloscopus borealis', 'Arctic Warbler', 'Birds'],
#  ['Physeter macrocephalus', 'sperm whale, North Pacific', 'Mammals'],
#  ['Picoides arcticus', 'Black-backed Woodpecker', 'Birds'],
#  ['Picoides dorsalis', 'American Threetoed Woodpecker', 'Birds'],
#  ['Picoides villosus', 'Hairy Woodpecker', 'Birds'],
#  ['Pinicola enucleator', 'Pine Grosbeak', 'Birds'],
#  ['Piranga ludoviciana', 'Western Tanager', 'Birds'],
#  ['Plecoptera', 'Stoneflies', 'Insects'],
#  ['Plectrophenax hyperboreus', "McKay's Bunting", 'Birds'],
#  ['Pluvialis dominica', 'American Golden-Plover', 'Birds'],
#  ['Pluvialis fulva', 'Pacific Golden-Plover', 'Birds'],
#  ['Pluvialis squatarola', 'Black-bellied Plover', 'Birds'],
#  ['Podiceps auritus', 'Horned Grebe', 'Birds'],
#  ['Podiceps grisegena', 'Red-necked Grebe', 'Birds'],
#  ['Podilymbus podiceps', 'Pied-billed Grebe', 'Birds'],
#  ['Podmosta weberi', 'A stonefly', 'Insects'],
#  ['Poecile cinctus', 'Gray-headed Chickadee', 'Birds'],
#  ['Poecile hudsonicus', 'Boreal Chickadee', 'Birds'],
#  ['Poecile rufescens', 'Chestnut-backed Chickadee', 'Birds'],
#  ['Polysticta stelleri', "Steller's Eider", 'Birds'],
#  ['Porzana carolina', 'Sora', 'Birds'],
#  ['Prosopium coulterii', 'pygmy whitefish', 'Fish'],
#  ['Prosopium cylindraceum', 'round whitefish', 'Fish'],
#  ['Pteronarcella regularis', 'A stonefly', 'Insects'],
#  ['Puffinus bulleri', "Buller's Shearwater", 'Birds'],
#  ['Puffinus creatopus', 'Pink-footed Shearwater', 'Birds'],
#  ['Pungitius pungitius', 'ninespine stickleback', 'Fish'],
#  ['Pusa hispida', 'ringed seal', 'Mammals'],
#  ['Raja binoculata', 'big skate', 'Fish'],
#  ['Rana luteiventris', 'Columbia spotted frog', 'Amphibians'],
#  ['Rangifer tarandus caribou', 'woodland caribou, Chisana herd', 'Mammals'],
#  ['Regulus satrapa', 'Golden-crowned Kinglet', 'Birds'],
#  ['Rhodostethia rosea', "Ross's Gull", 'Birds'],
#  ['Riparia riparia', 'Bank Swallow', 'Birds'],
#  ['Rissa brevirostris', 'Red-legged Kittiwake', 'Birds'],
#  ['Rissa tridactyla', 'Black-legged Kittiwake', 'Birds'],
#  ['Selasphorus rufus', 'Rufous Hummingbird', 'Birds'],
#  ['Setophaga ruticilla', 'American Redstart', 'Birds'],
#  ['Setophaga striata', 'Blackpoll Warbler', 'Birds'],
#  ['Setophaga townsendi', "Townsend's Warbler", 'Birds'],
#  ['Sialia currucoides', 'Mountain Bluebird', 'Birds'],
#  ['Sitta canadensis', 'Red-breasted Nuthatch', 'Birds'],
#  ['Somateria fischeri', 'Spectacled Eider', 'Birds'],
#  ['Somateria mollissima v-nigrum', 'Pacific Common Eider', 'Birds'],
#  ['Somateria spectabilis', 'King Eider', 'Birds'],
#  ['Sorex alaskanus', 'Glacier Bay water shrew', 'Mammals'],
#  ['Sorex hoyi', 'pygmy shrew', 'Mammals'],
#  ['Sorex jacksoni', 'St. Lawrence Island shrew', 'Mammals'],
#  ['Sorex monticolus', 'dusky shrew', 'Mammals'],
#  ['Sorex monticolus alascensis', 'dusky shrew, Yakutat', 'Mammals'],
#  ['Sorex monticolus elassodon',
#   'dusky shrew, Queen Charlotte Islands',
#   'Mammals'],
#  ['Sorex monticolus malitiosus', 'dusky shrew, Warren Island', 'Mammals'],
#  ['Sorex palustris', 'water shrew', 'Mammals'],
#  ['Sorex pribilofensis', 'Pribilof Island shrew', 'Mammals'],
#  ['Sorex tundrensis', 'tundra shrew', 'Mammals'],
#  ['Sorex yukonicus', 'tiny shrew', 'Mammals'],
#  ['Sphyrapicus ruber', 'Red-breasted Sapsucker', 'Birds'],
#  ['Sphyrapicus varius', 'Yellow-bellied Sapsucker', 'Birds'],
#  ['Spinus pinus', 'Pine Siskin', 'Birds'],
#  ['Spirinchus thaleichthys', 'longfin smelt', 'Fish'],
#  ['Spizelloides arborea', 'American Tree Sparrow', 'Birds'],
#  ['Stelgidopteryx ruficollis', 'Northern Roughwinged Swallow', 'Birds'],
#  ['Stercorarius maccormicki', 'South Polar Skua', 'Birds'],
#  ['Sterna hirundo', 'Common Tern', 'Birds'],
#  ['Sterna paradisaea', 'Arctic Tern', 'Birds'],
#  ['Strix nebulosa', 'Great Gray Owl', 'Birds'],
#  ['Strix varia', 'Barred Owl', 'Birds'],
#  ['Stygobromus quatsinensis', 'A cave obligate amphipod', 'Crustaceans'],
#  ['Surnia ulula', 'Northern Hawk Owl', 'Birds'],
#  ['Synaptomys borealis', 'northern bog lemming', 'Mammals'],
#  ['Synthliboramphus antiquus', 'Ancient Murrelet', 'Birds'],
#  ['Tachycineta thalassina', 'Violet-green Swallow', 'Birds'],
#  ['Tamiasciurus hudsonicus kenaiensis', 'red squirrel, Kenai', 'Mammals'],
#  ['Tamiasciurus hudsonicus picatus', 'red squirrel, Kupreanof', 'Mammals'],
#  ['Taricha granulosa', 'Rough-skinned newt', 'Amphibians'],
#  ['Thaleichthys pacificus', 'eulachon', 'Fish'],
#  ['Trichodon trichodon', 'Pacific sandfish', 'Fish'],
#  ['Trichoptera', 'Caddisflies', 'Insects'],
#  ['Tringa brevipes', 'Gray-tailed Tattler', 'Birds'],
#  ['Tringa flavipes', 'Lesser Yellowlegs', 'Birds'],
#  ['Tringa incana', 'Wandering Tattler', 'Birds'],
#  ['Tringa nebularia', 'Common Greenshank', 'Birds'],
#  ['Tringa solitaria', 'Solitary Sandpiper', 'Birds'],
#  ['Tringa solitaria cinnamomea', 'Solitary Sandpiper', 'Birds'],
#  ['Troglodytes pacificus alascensis', 'Pribilof Winter Wren', 'Birds'],
#  ['Troglodytes pacificus helleri', 'Kodiak Winter Wren', 'Birds'],
#  ['Troglodytes pacificus kiskensis', 'Kiska Winter Wren', 'Birds'],
#  ['Troglodytes pacificus meligerus', 'Attu Winter Wren', 'Birds'],
#  ['Troglodytes pacificus petrophilus', 'Unalaska Winter Wren', 'Birds'],
#  ['Troglodytes pacificus semidiensis', 'Sedimi Winter Wren', 'Birds'],
#  ['Troglodytes pacificus stevensoni', "Stevenson's Winter Wren", 'Birds'],
#  ['Troglodytes pacificus tanagensis', 'Tanaga Winter Wren', 'Birds'],
#  ['Tryngites subruficollis', 'Buff-breasted Sandpiper', 'Birds'],
#  ['Turdus migratorius', 'American Robin', 'Birds'],
#  ['Turdus obscurus', 'Eyebrowed Thrush', 'Birds'],
#  ['Tyrannus tyrannus', 'Eastern Kingbird', 'Birds'],
#  ['Uria aalge', 'Common Murre', 'Birds'],
#  ['Uria lomvia', 'Thick-billed Murre', 'Birds'],
#  ['Urocitellus parryii', 'arctic ground squirrel', 'Mammals'],
#  ['Urocitellus parryii ablusus', 'arctic ground squirrel', 'Mammals'],
#  ['Urocitellus parryii kennicottii',
#   'arctic ground squirrel, Barrow',
#   'Mammals'],
#  ['Urocitellus parryii kodiacensis',
#   'arctic ground squirrel, Kodiak Island',
#   'Mammals'],
#  ['Urocitellus parryii lyratus',
#   'arctic ground squirrel, St. Lawrence Island',
#   'Mammals'],
#  ['Urocitellus parryii nebulicola',
#   'arctic ground squirrel, Shumagin Islands',
#   'Mammals'],
#  ['Urocitellus parryii osgoodi',
#   "arctic ground squirrel, Osgood's",
#   'Mammals'],
#  ['Ursus arctos alascensis', 'brown bear, Kenai population', 'Mammals'],
#  ['Ursus maritimus', 'polar bear', 'Mammals'],
#  ['Valvata lewisi', 'Fringed valvata', 'Mollusks'],
#  ['Valvata mergella', 'Rams-horn valvata', 'Mollusks'],
#  ['Vertigo', 'Undescribed snail', 'Mollusks'],
#  ['Vireo cassinii', "Cassin's Vireo", 'Birds'],
#  ['Vireo olivaceus', 'Red-eyed Vireo', 'Birds'],
#  ['Zaprora silenus', 'prowfish', 'Fish'],
#  ['Zapus hudsonius', 'meadow jumping mouse', 'Mammals'],
#  ['Ziphius cavirostris', "Cuvier's beaked whale", 'Mammals'],
#  ['Zonotrichia atricapilla', 'Golden-crowned Sparrow', 'Birds'],
#  ['Zonotrichia leucophrys', 'White-crowned Sparrow', 'Birds'],
#  ['Zonotrichia querula', "Harris's Sparrow", 'Birds']]
